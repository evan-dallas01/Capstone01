# %%
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ADULT VAX DATA ________

# %%
adult_vax=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Adult_vax.csv')

# %%
adult_vax.loc[adult_vax['Survey Year']==2018].Vaccine.unique()
# Out:
# array(['Pneumococcal', 'Tdap', 'Td or Tdap', 'Zoster (Shingles)'],
#       dtype=object)

# %%
pne_vax_2018=adult_vax.loc[(adult_vax['Survey Year']==2018)&(adult_vax['Vaccine']=='Pneumococcal')&(adult_vax['Geography Type']=='States/Local Areas')&(adult_vax['Dimension']=='Overall')&(adult_vax['Dimension Type']=='>=65 Years')]

# %%
pne_vax_2018=pne_vax_2018[['Geography', 'Estimate (%)']]

# %%
pne_vax_2018=pne_vax_2018.rename(columns={'Geography':'State', 'Estimate (%)':'Percentage_Pneumococcal'})

# %%
pne_vax_2018.to_csv('pne_vax_2018.csv')

# %%
pne_vax_2018_f=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/pne_vax_2018.csv')

# %%
pne_vax_2018_f=pne_vax_2018_f.drop(columns=['Unnamed: 0'])

# %%
pne_vax_2018_f
# Out:
#    State  Percentage_Pneumococcal
# 0     AL                     71.7
# 1     AK                     64.2
# 2     AZ                     74.0
# 3     AR                     75.0
# 4     CA                     68.9
# 5     CO                     77.5
# 6     CT                     72.4
# 7     DE                     73.0
# 8     DC                     71.0
# 9     FL                     67.3
# 10    GA                     71.2
# 11    HI                     65.3
# 12    ID                     70.5
# 13    IL                     68.6
# 14    IN                     72.5
# 15    IA                     76.3
# 16    KS                     76.2
# 17    KY                     72.6
# 18    LA                     68.6
# 19    ME                     77.2
# 20    MD                     75.7
# 21    MA                     73.4
# 22    MI                     74.2
# 23    MN                     72.7
# 24    MS                     68.7
# 25    MO                     74.4
# 26    MT                     73.3
# 27    NE                     76.6
# 28    NV                     68.5
# 29    NH                     78.6
# 30    NJ                     68.1
# 31    NM                     71.3
# 32    NY                     64.0
# 33    NC                     76.7
# 34    ND                     75.2
# 35    OH                     74.3
# 36    OK                     75.1
# 37    OR                     77.3
# 38    PA                     75.3
# 39    RI                     75.5
# 40    SC                     73.6
# 41    SD                     77.0
# 42    TN                     74.5
# 43    TX                     71.3
# 44    UT                     73.7
# 45    VT                     74.8
# 46    VA                     73.9
# 47    WA                     78.0
# 48    WV                     73.0
# 49    WI                     74.9
# 50    WY                     70.1

# %% [markdown]
# ADOLESCENT VAX DATA _______

# %%
ado_2018['Vaccine/Sample'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12404\48131541.py in <module>
# ----> 1 ado_2018['Vaccine/Sample'].unique()
#
# NameError: name 'ado_2018' is not defined

# %%
ado_vax=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Adolescent_Vax-13-17.csv')

# %%
ado_2018=ado_vax.loc[ado_vax['Survey Year']=='2018']

# %%
ado_mmr_2018=ado_2018.loc[ado_2018['Vaccine/Sample']=='MMR']

# %%
ado_mmr_2018.to_csv('adolescent_mmr_2018.csv')

# %%
ado_vax.loc[(ado_vax['Survey Year']=='2020')&(ado_vax['Geography']=='Tennessee')]

# %%
ado_vax.loc[(ado_vax['Vaccine/Sample']=='HPV')&(ado_vax['Survey Year']=='2020')&(ado_vax['Dose']=='Up-to-Date, Males and Females'), ('Geography', 'Dimension', 'Estimate (%)')]

# %%
ado_mmr_2018_f=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/adolescent_mmr_2018.csv')

# %%
ado_mmr_2018_f=ado_mmr_2018_f.drop(columns=['Unnamed: 0', 'Dimension Type', 'Geography Type', 'Dose'])

# %%
ado_mmr_2018_f=ado_mmr_2018_f.rename(columns={'Geography':'State', 'Estimate (%)':'Percentage_MMR', 'Sample Size':'sample_size_mmr'})

# %%
ado_mmr_2018_f=ado_mmr_2018_f[['State', 'Percentage_MMR']]

# %%
hpv_vax_2018=ado_2018.loc[ado_2018['Vaccine/Sample']=='HPV']

# %%
hpv_vax_2018=hpv_vax_2018.loc[hpv_vax_2018['Dose']=='Up-to-Date, Males and Females']

# %%
hpv_vax_2018=hpv_vax_2018[['Geography', 'Estimate (%)']]

# %%
hpv_vax_2018=hpv_vax_2018.rename(columns={'Geography':'State', 'Estimate (%)': 'Percentage_HPV'})

# %%
hpv_vax_2018.to_csv('hpv_vax_2018.csv')

# %%
hpv_vax_2018_f=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/hpv_vax_2018.csv')

# %%
hpv_vax_2018_f=hpv_vax_2018_f.drop(columns=['Unnamed: 0'])

# %%
hepb_vax_2018=ado_2018.loc[ado_2018['Vaccine/Sample']=='HepB']

# %%
hepb_vax_2018[['Geography', 'Estimate (%)']].to_csv('hepb_vax_2018.csv')

# %%
hepb_vax_2018_f=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/hepb_vax_2018.csv')

# %%
hepb_vax_2018_f=hepb_vax_2018_f.drop(columns=['Unnamed: 0'])

# %%
hepb_vax_2018_f=hepb_vax_2018_f.rename(columns={'Geography':'State', 'Estimate (%)':'Percentage_HepB'})

# %%
hepb_vax_2018_f
# Out:
#    State  Percentage_HepB
# 0     AL             94.2
# 1     AK             89.5
# 2     AZ             89.1
# 3     AR             91.4
# 4     CA             88.8
# 5     CO             93.5
# 6     CT             95.9
# 7     DE             94.3
# 8     DC              NaN
# 9     FL             97.6
# 10    GA             95.4
# 11    GU             77.5
# 12    HI             93.4
# 13    ID             88.4
# 14    IL             94.5
# 15    IN             95.9
# 16    IA             95.5
# 17    KS             85.8
# 18    KY             91.9
# 19    LA             93.4
# 20    ME             94.5
# 21    MD             93.4
# 22    MA             97.9
# 23    MI             91.6
# 24    MN             93.8
# 25    MS             91.9
# 26    MO             90.7
# 27    MT             88.9
# 28    NE             91.9
# 29    NV             88.0
# 30    NH             97.3
# 31    NJ             93.4
# 32    NM             91.4
# 33    NY             95.9
# 34    NC             93.2
# 35    ND             97.5
# 36    OH             94.7
# 37    OK             88.0
# 38    OR             93.5
# 39    PA             97.2
# 40    PR              NaN
# 41    US             92.1
# 42    RI             96.9
# 43    SC             93.0
# 44    SD             95.0
# 45    TN             95.1
# 46    TX             83.5
# 47    UT             90.9
# 48    VT             96.6
# 49    VA             91.7
# 50    WA             90.1
# 51    WV             88.2
# 52    WI             94.3
# 53    WY             91.1

# %%
hpv_vax_2021=ado_vax.loc[(ado_vax['Survey Year']=='2021')&(ado_vax['Vaccine/Sample']=='HPV')&(ado_vax['Dose']=='Up-to-Date, Males and Females')&(ado_vax['Dimension']=='13-17 Years'), ('Geography', 'Estimate (%)')]

# %%
hpv_vax_2021.to_csv('hpv_vax_2021.csv')

# %%
hpv_vax_2021_f=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/hpv_vax_2021.csv')

# %%
hpv_vax_2021_f=hpv_vax_2021_f.drop(columns=['Unnamed: 0'])

# %%
hpv_vax_2021_f=hpv_vax_2021_f.rename(columns={'Geography':'State', 'Estimate (%)':'Percentage_HPV'})

# %%
hepb_vax_2021=ado_vax.loc[(ado_vax['Survey Year']=='2021')&(ado_vax['Vaccine/Sample']=='HepB'), ('Geography', 'Estimate (%)')]

# %%
hepb_vax_2021.to_csv('hepb_vax_2021.csv')

# %%
hepb_vax_2021_f=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/hepb_vax_2021.csv')

# %%
hepb_vax_2021_f=hepb_vax_2021_f.drop(columns=['Unnamed: 0'])

# %%
hepb_vax_2021_f=hepb_vax_2021_f.rename(columns={'Geography':'State', 'Estimate (%)':'Percentage_HepB'})

# %%
hepb_vax_2021_f
# Out:
#    State  Percentage_HepB
# 0     AL             92.4
# 1     AK             90.5
# 2     AZ             86.2
# 3     AR             94.1
# 4     CA             90.5
# 5     CO             93.8
# 6     CT             96.4
# 7     DE             91.0
# 8     DC             85.6
# 9     FL             95.7
# 10    GA             95.9
# 11    GU             81.8
# 12    HI             93.8
# 13    ID             90.8
# 14    IL             96.1
# 15    IN             92.9
# 16    IA             97.6
# 17    KS             93.1
# 18    KY             94.9
# 19    LA             91.8
# 20    ME             92.5
# 21    MD             93.2
# 22    MA             95.9
# 23    MI             90.6
# 24    MN             96.1
# 25    MS             91.0
# 26    MO             90.7
# 27    MT             91.2
# 28    NE             92.9
# 29    NV             89.9
# 30    NH             96.9
# 31    NJ             91.5
# 32    NM             88.0
# 33    NY             96.2
# 34    NC             95.5
# 35    ND             93.1
# 36    OH             94.1
# 37    OK             90.4
# 38    OR             92.7
# 39    PA             92.6
# 40    PR             84.0
# 41    US             92.3
# 42    RI             96.3
# 43    SC             95.0
# 44    SD             97.2
# 45    TN             95.1
# 46    TX             84.4
# 47    UT             94.3
# 48    VT             94.1
# 49    VA             92.2
# 50    WA             90.6
# 51    WV             86.1
# 52    WI             95.2
# 53    WY             89.1

# %%
mmr_vax_2021=ado_vax.loc[(ado_vax['Survey Year']=='2021')&(ado_vax['Vaccine/Sample']=='MMR'), ('Geography', 'Estimate (%)')]

# %%
mmr_vax_2021=mmr_vax_2021.rename(columns={'Geography':'State', 'Estimate (%)':'Percentage_MMR'})

# %%
mmr_vax_2021.to_csv('mmr_vax_2021.csv')

# %%
mmr_vax_2021_f=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/mmr_vax_2021.csv')

# %%
mmr_vax_2021_f=mmr_vax_2021_f.drop(columns=['Unnamed: 0'])

# %%
adult_vax.Vaccine.unique()
# Out:
# array(['Pneumococcal', 'Tdap', 'Td or Tdap', 'Zoster (Shingles)'],
#       dtype=object)

# %%
pne_vax=adult_vax.loc[adult_vax.Vaccine=='Pneumococcal']

# %%
pne_vax21=pne_vax.loc[pne_vax['Survey Year']==2021]

# %%
pne_vax21=adult_vax.loc[(adult_vax['Survey Year']==2021)&(adult_vax['Vaccine']=='Pneumococcal')&(adult_vax['Geography Type']=='States/Local Areas')&(adult_vax['Dimension']=='Overall')&(adult_vax['Dimension Type']=='>=65 Years')]

# %%
pne_vax21=pne_vax21[['Geography','Estimate (%)']]

# %%
pne_vax21.to_csv('pne_vax21.csv')

# %%
pne_vax21_f=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/pne_vax21.csv')

# %%
pne_vax21_f=pne_vax21_f.drop(columns=['Unnamed: 0'])

# %%
pne_vax21_f=pne_vax21_f.rename(columns={'Geography':'State', 'Estimate (%)':'Percent_pneumococcal'})

# %%
vax_df=mmr_vax_2021_f.merge(pne_vax21_f, how='inner', on='State')

# %%
vax_df=vax_df.merge(hepb_vax_2021_f, how='inner', on='State')

# %%
vax_df=vax_df.merge(hpv_vax_2021_f, how='inner', on='State')

# %%
vax_df
# Out:
#    State  Percentage_MMR  Percent_pneumococcal  Percentage_HepB  \
# 0     AL            95.8                  70.1             92.4
# 1     AK            91.8                  64.4             90.5
# 2     AZ            86.4                  69.1             86.2
# 3     AR            94.0                  70.7             94.1
# 4     CA            89.3                  65.4             90.5
# 5     CO            95.6                  76.3             93.8
# 6     CT            96.2                  72.9             96.4
# 7     DE            92.5                  72.8             91.0
# 8     DC            87.8                  72.2             85.6
# 9     FL            95.2                   NaN             95.7
# 10    GA            95.5                  70.2             95.9
# 11    GU            78.7                  26.9             81.8
# 12    HI            91.6                  60.4             93.8
# 13    ID            89.2                  68.3             90.8
# 14    IL            96.0                  70.9             96.1
# 15    IN            92.5                  73.1             92.9
# 16    IA            97.7                  75.4             97.6
# 17    KS            94.6                  74.4             93.1
# 18    KY            94.6                  65.9             94.9
# 19    LA            94.1                  69.5             91.8
# 20    ME            94.9                  72.4             92.5
# 21    MD            94.8                  74.4             93.2
# 22    MA            97.0                  71.2             95.9
# 23    MI            88.9                  72.0             90.6
# 24    MN            95.2                  71.0             96.1
# 25    MS            92.3                  63.2             91.0
# 26    MO            88.3                  72.9             90.7
# 27    MT            94.2                  69.3             91.2
# 28    NE            94.0                  75.3             92.9
# 29    NV            90.3                  64.3             89.9
# 30    NH            97.2                  75.1             96.9
# 31    NJ            90.0                  64.2             91.5
# 32    NM            88.1                  68.6             88.0
# 33    NY            94.2                  65.6             96.2
# 34    NC            95.3                  75.2             95.5
# 35    ND            98.3                  70.4             93.1
# 36    OH            95.0                  70.7             94.1
# 37    OK            91.8                  75.3             90.4
# 38    OR            92.4                  75.5             92.7
# 39    PA            92.7                  70.3             92.6
# 40    PR            80.9                  34.1             84.0
# 41    RI            94.8                  74.6             96.3
# 42    SC            95.3                  70.9             95.0
# 43    SD            98.0                  74.2             97.2
# 44    TN            95.1                  69.9             95.1
# 45    TX            84.1                  69.0             84.4
# 46    UT            93.1                  73.4             94.3
# 47    VT            97.1                  70.6             94.1
# 48    VA            94.8                  75.0             92.2
# 49    WA            93.2                  75.4             90.6
# 50    WV            87.6                  72.0             86.1
# 51    WI            98.6                  71.8             95.2
# 52    WY            91.3                  66.8             89.1
#
#     Percentage_HPV
# 0             62.5
# 1             56.2
# 2             61.7
# 3             56.8
# 4             69.0
# 5             69.2
# 6             66.4
# 7             68.9
# 8             79.4
# 9             49.0
# 10            60.9
# 11            54.0
# 12            69.3
# 13            61.6
# 14            62.2
# 15            55.2
# 16            66.1
# 17            64.3
# 18            57.0
# 19            63.9
# 20            61.5
# 21            71.9
# 22            75.0
# 23            64.7
# 24            65.7
# 25            32.7
# 26            59.3
# 27            52.6
# 28            61.9
# 29            56.5
# 30            72.3
# 31            54.8
# 32            57.9
# 33            64.4
# 34            67.8
# 35            72.2
# 36            62.2
# 37            56.7
# 38            67.0
# 39            68.7
# 40            67.2
# 41            83.2
# 42            62.1
# 43            74.7
# 44            56.5
# 45            51.5
# 46            61.4
# 47            66.7
# 48            64.9
# 49            67.8
# 50            56.4
# 51            63.3
# 52            48.0

# %%
pubschool=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/pubschool.csv')
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\1585000740.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   pubschool=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/pubschool.csv')

# %%
pubschool
# Out:
#                 X          Y  OBJECTID       NCESSCH   SURVYEAR STABR  \
# 0      -86.206200  34.260200         1   10000500870  2020-2021    AL
# 1      -86.204900  34.262200         2   10000500871  2020-2021    AL
# 2      -86.220100  34.273300         3   10000500879  2020-2021    AL
# 3      -86.221806  34.252700         4   10000500889  2020-2021    AL
# 4      -86.193300  34.289800         5   10000501616  2020-2021    AL
# ...           ...        ...       ...           ...        ...   ...
# 100717 -64.917602  18.341950    100718  780003000024  2020-2021    VI
# 100718 -64.952483  18.338742    100719  780003000026  2020-2021    VI
# 100719 -64.899024  18.354782    100720  780003000027  2020-2021    VI
# 100720 -64.945940  18.336658    100721  780003000033  2020-2021    VI
# 100721 -64.890311  18.318230    100722  780003000034  2020-2021    VI
#
#           LEAID ST_LEAID                                   LEA_NAME  \
# 0        100005   AL-101                           Albertville City
# 1        100005   AL-101                           Albertville City
# 2        100005   AL-101                           Albertville City
# 3        100005   AL-101                           Albertville City
# 4        100005   AL-101                           Albertville City
# ...         ...      ...                                        ...
# 100717  7800030   VI-001  Saint Thomas - Saint John School District
# 100718  7800030   VI-001  Saint Thomas - Saint John School District
# 100719  7800030   VI-001  Saint Thomas - Saint John School District
# 100720  7800030   VI-001  Saint Thomas - Saint John School District
# 100721  7800030   VI-001  Saint Thomas - Saint John School District
#
#                                  SCH_NAME  ...  HIALF     HI TRALM TRALF  \
# 0               Albertville Middle School  ...  230.0  469.0  19.0  10.0
# 1                 Albertville High School  ...  371.0  785.0  17.0  21.0
# 2         Albertville Intermediate School  ...  253.0  481.0  17.0  12.0
# 3           Albertville Elementary School  ...  237.0  497.0   7.0   8.0
# 4       Albertville Kindergarten and PreK  ...  137.0  288.0   6.0   7.0
# ...                                   ...  ...    ...    ...   ...   ...
# 100717         LOCKHART ELEMENTARY SCHOOL  ...   29.0   59.0   1.0   1.0
# 100718    ULLA F MULLER ELEMENTARY SCHOOL  ...   34.0   64.0   2.0   1.0
# 100719    YVONNE BOWSKY ELEMENTARY SCHOOL  ...   25.0   57.0   NaN   NaN
# 100720         CANCRYN JUNIOR HIGH SCHOOL  ...   72.0  153.0   1.0   NaN
# 100721       BERTHA BOSCHULTE JUNIOR HIGH  ...   30.0   55.0   NaN   NaN
#
#           TR  WHALM  WHALF     WH     LATCOD     LONCOD
# 0       29.0  187.0  184.0  371.0  34.260200 -86.206200
# 1       38.0  368.0  338.0  706.0  34.262200 -86.204900
# 2       29.0  177.0  168.0  345.0  34.273300 -86.220100
# 3       15.0  180.0  160.0  340.0  34.252700 -86.221806
# 4       13.0  108.0  108.0  216.0  34.289800 -86.193300
# ...      ...    ...    ...    ...        ...        ...
# 100717   2.0    2.0    4.0    6.0  18.341950 -64.917602
# 100718   3.0    4.0    5.0    9.0  18.338742 -64.952483
# 100719   NaN    6.0    3.0    9.0  18.354782 -64.899024
# 100720   1.0    7.0   11.0   18.0  18.336658 -64.945940
# 100721   NaN    1.0    1.0    2.0  18.318230 -64.890311
#
# [100722 rows x 79 columns]

# %%
pubschool.groupby('STABR').count().sort_values('SCH_NAME', ascending=False)
# Out:
#            X      Y  OBJECTID  NCESSCH  SURVYEAR  LEAID  ST_LEAID  LEA_NAME  \
# STABR
# CA     10330  10330     10330    10330     10330  10330     10330     10330
# TX      9467   9467      9467     9467      9467   9467      9467      9467
# NY      4831   4831      4831     4831      4831   4831      4831      4831
# IL      4384   4384      4384     4384      4384   4384      4384      4384
# FL      4267   4267      4267     4267      4267   4267      4267      4267
# MI      3553   3553      3553     3553      3553   3553      3553      3553
# OH      3532   3532      3532     3532      3532   3532      3532      3532
# PA      2952   2952      2952     2952      2952   2952      2952      2952
# NC      2730   2730      2730     2730      2730   2730      2730      2730
# NJ      2566   2566      2566     2566      2566   2566      2566      2566
# MN      2542   2542      2542     2542      2542   2542      2542      2542
# WA      2507   2507      2507     2507      2507   2507      2507      2507
# AZ      2480   2480      2480     2480      2480   2480      2480      2480
# MO      2460   2460      2460     2460      2460   2460      2460      2460
# GA      2311   2311      2311     2311      2311   2311      2311      2311
# WI      2258   2258      2258     2258      2258   2258      2258      2258
# VA      2130   2130      2130     2130      2130   2130      2130      2130
# CO      1927   1927      1927     1927      1927   1927      1927      1927
# IN      1902   1902      1902     1902      1902   1902      1902      1902
# TN      1880   1880      1880     1880      1880   1880      1880      1880
# MA      1845   1845      1845     1845      1845   1845      1845      1845
# OK      1790   1790      1790     1790      1790   1790      1790      1790
# AL      1559   1559      1559     1559      1559   1559      1559      1559
# KY      1532   1532      1532     1532      1532   1532      1532      1532
# MD      1421   1421      1421     1421      1421   1421      1421      1421
# LA      1354   1354      1354     1354      1354   1354      1354      1354
# KS      1310   1310      1310     1310      1310   1310      1310      1310
# IA      1309   1309      1309     1309      1309   1309      1309      1309
# SC      1280   1280      1280     1280      1280   1280      1280      1280
# OR      1263   1263      1263     1263      1263   1263      1263      1263
# UT      1113   1113      1113     1113      1113   1113      1113      1113
# NE      1086   1086      1086     1086      1086   1086      1086      1086
# AR      1080   1080      1080     1080      1080   1080      1080      1080
# MS      1042   1042      1042     1042      1042   1042      1042      1042
# CT      1001   1001      1001     1001      1001   1001      1001      1001
# NM       886    886       886      886       886    886       886       886
# PR       849    849       849      849       849    849       849       849
# MT       829    829       829      829       829    829       829       829
# ID       791    791       791      791       791    791       791       791
# NV       754    754       754      754       754    754       754       754
# SD       722    722       722      722       722    722       722       722
# WV       711    711       711      711       711    711       711       711
# ME       602    602       602      602       602    602       602       602
# ND       531    531       531      531       531    531       531       531
# AK       509    509       509      509       509    509       509       509
# NH       496    496       496      496       496    496       496       496
# WY       364    364       364      364       364    364       364       364
# RI       314    314       314      314       314    314       314       314
# VT       305    305       305      305       305    305       305       305
# HI       295    295       295      295       295    295       295       295
# DC       235    235       235      235       235    235       235       235
# DE       230    230       230      230       230    230       230       230
# BI       174    174       174      174       174    174       174       174
# GU        44     44        44       44        44     44        44        44
# MP        35     35        35       35        35     35        35        35
# AS        29     29        29       29        29     29        29        29
# VI        23     23        23       23        23     23        23        23
#
#        SCH_NAME  LSTREET1  ...  HIALF     HI  TRALM  TRALF    TR  WHALM  \
# STABR                      ...
# CA        10330     10330  ...  10116  10128   9356   9352  9699   9840
# TX         9467      9467  ...   8997   8997   8997   8997  8997   8997
# NY         4831      4831  ...   4710   4766   4135   4149  4435   4673
# IL         4384      4384  ...   3599   3722   3397   3357  3597   3626
# FL         4267      4267  ...   4213   4213   4213   4213  4213   4213
# MI         3553      3553  ...   3526   3526   3526   3526  3526   3526
# OH         3532      3532  ...   3531   3531   3531   3531  3531   3531
# PA         2952      2952  ...   2946   2946   2946   2946  2946   2946
# NC         2730      2730  ...   2679   2679   2679   2679  2679   2679
# NJ         2566      2566  ...   2527   2541   2140   2140  2262   2469
# MN         2542      2542  ...   2353   2444   2327   2282  2387   2471
# WA         2507      2507  ...   2465   2487   2382   2379  2433   2495
# AZ         2480      2480  ...   2350   2350   2350   2350  2350   2350
# MO         2460      2460  ...   2102   2242   2035   2040  2141   2410
# GA         2311      2311  ...   2307   2307   2307   2307  2307   2307
# WI         2258      2258  ...   2125   2198   2054   2073  2162   2206
# VA         2130      2130  ...   2118   2118   2118   2118  2118   2118
# CO         1927      1927  ...   1911   1913   1733   1734  1815   1913
# IN         1902      1902  ...   1843   1885   1850   1841  1880   1894
# TN         1880      1880  ...   1796   1843   1718   1708  1785   1837
# MA         1845      1845  ...   1810   1829   1750   1723  1797   1832
# OK         1790      1790  ...   1698   1753   1789   1787  1789   1783
# AL         1559      1559  ...   1347   1347   1347   1347  1347   1347
# KY         1532      1532  ...   1465   1500   1445   1444  1486   1524
# MD         1421      1421  ...   1383   1409   1315   1304  1362   1378
# LA         1354      1354  ...   1280   1310   1235   1240  1298   1313
# KS         1310      1310  ...   1253   1282   1169   1176  1229   1310
# IA         1309      1309  ...   1250   1285   1184   1149  1242   1309
# SC         1280      1280  ...   1266   1266   1266   1266  1266   1266
# OR         1263      1263  ...   1263   1263   1263   1263  1263   1263
# UT         1113      1113  ...   1023   1034    948    939   975   1043
# NE         1086      1086  ...   1009   1009   1009   1009  1009   1009
# AR         1080      1080  ...   1042   1061    927    912   981   1066
# MS         1042      1042  ...    905    960    932    929   976   1001
# CT         1001      1001  ...    998   1000    977    964   992    998
# NM          886       886  ...    873    879    573    565   645    844
# PR          849       849  ...    841    841      0      0     0    147
# MT          829       829  ...    826    826    826    826   826    826
# ID          791       791  ...    772    772    772    772   772    772
# NV          754       753  ...    720    720    720    720   720    720
# SD          722       722  ...    706    706    706    706   706    706
# WV          711       711  ...    411    496    539    527   594    672
# ME          602       602  ...    436    500    442    447   492    568
# ND          531       531  ...    394    426    342    349   394    474
# AK          509       509  ...    503    503    503    503   503    503
# NH          496       496  ...    416    447    403    406   436    496
# WY          364       364  ...    364    364    364    364   364    364
# RI          314       314  ...    301    305    298    292   304    305
# VT          305       305  ...    248    278    223    227   247    305
# HI          295       295  ...    293    294    294    294   294    286
# DC          235       235  ...    216    228    152    151   171    146
# DE          230       228  ...    221    225    217    215   220    225
# BI          174       174  ...      4      4      4      4     4      4
# GU           44        44  ...     41     41     41     41    41     41
# MP           35        35  ...      0      0      0      0     0      0
# AS           29        29  ...      1      3      0      0     0      3
# VI           23        23  ...     22     22     10     11    14     18
#
#        WHALF    WH  LATCOD  LONCOD
# STABR
# CA      9812  9984   10330   10330
# TX      8997  8997    9467    9467
# NY      4624  4752    4831    4831
# IL      3609  3685    4384    4384
# FL      4213  4213    4267    4267
# MI      3526  3526    3553    3553
# OH      3531  3531    3532    3532
# PA      2946  2946    2952    2952
# NC      2679  2679    2730    2730
# NJ      2452  2500    2566    2566
# MN      2461  2489    2542    2542
# WA      2490  2500    2507    2507
# AZ      2350  2350    2480    2480
# MO      2408  2420    2460    2460
# GA      2307  2307    2311    2311
# WI      2199  2215    2258    2258
# VA      2118  2118    2130    2130
# CO      1911  1917    1927    1927
# IN      1885  1899    1902    1902
# TN      1813  1856    1880    1880
# MA      1827  1837    1845    1845
# OK      1779  1783    1790    1790
# AL      1347  1347    1559    1559
# KY      1523  1529    1532    1532
# MD      1380  1404    1421    1421
# LA      1296  1323    1354    1354
# KS      1310  1310    1310    1310
# IA      1309  1309    1309    1309
# SC      1266  1266    1280    1280
# OR      1263  1263    1263    1263
# UT      1040  1045    1113    1113
# NE      1009  1009    1086    1086
# AR      1057  1068    1080    1080
# MS      1003  1019    1042    1042
# CT       998  1001    1001    1001
# NM       835   856     886     886
# PR       132   227     849     849
# MT       826   826     829     829
# ID       772   772     791     791
# NV       720   720     754     754
# SD       706   706     722     722
# WV       663   672     711     711
# ME       568   568     602     602
# ND       472   476     531     531
# AK       503   503     509     509
# NH       496   496     496     496
# WY       364   364     364     364
# RI       305   306     314     314
# VT       305   305     305     305
# HI       279   287     295     295
# DC       138   160     235     235
# DE       224   225     230     230
# BI         4     4     174     174
# GU        41    41      44      44
# MP         0     0      35      35
# AS         5     6      29      29
# VI        19    21      23      23
#
# [57 rows x 78 columns]

# %%
elem_schools=pubschool.loc[pubschool['SCHOOL_LEVEL']=='Elementary']

# %%
percent_elem=(round(elem_schools.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME/(pubschool.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME)*100, 3).reset_index())

# %%
percent_elem=percent_elem.rename(columns={'STABR':'State', 'SCH_NAME':'Percent_elem'})

# %%
percent_elem
# Out:
#    State  Percent_elem
# 0     AK        33.792
# 1     AL        45.093
# 2     AR        47.685
# 3     AS        79.310
# 4     AZ        48.669
# 5     BI        62.069
# 6     CA        57.783
# 7     CO        54.229
# 8     CT        60.340
# 9     DC        60.851
# 10    DE        51.739
# 11    FL        52.144
# 12    GA        56.772
# 13    GU        61.364
# 14    HI        62.373
# 15    IA        52.101
# 16    ID        49.052
# 17    IL        53.490
# 18    IN        55.521
# 19    KS        55.267
# 20    KY        47.258
# 21    LA        53.250
# 22    MA        57.073
# 23    MD        62.562
# 24    ME        58.638
# 25    MI        46.665
# 26    MN        38.749
# 27    MO        49.715
# 28    MP        25.714
# 29    MS        42.418
# 30    MT        51.628
# 31    NC        54.396
# 32    ND        51.224
# 33    NE        49.816
# 34    NH        57.460
# 35    NJ        58.418
# 36    NM        51.580
# 37    NV        56.499
# 38    NY        53.053
# 39    OH        50.340
# 40    OK        52.179
# 41    OR        56.453
# 42    PA        55.556
# 43    PR        60.895
# 44    RI        55.732
# 45    SC        54.062
# 46    SD        45.429
# 47    TN        54.468
# 48    TX        49.741
# 49    UT        56.244
# 50    VA        53.850
# 51    VI        65.217
# 52    VT        68.197
# 53    WA        48.664
# 54    WI        50.000
# 55    WV        57.806
# 56    WY        53.297

# %%
highschool=pubschool.loc[pubschool['SCHOOL_LEVEL']=='High']

# %%
highschool
# Out:
#                 X          Y  OBJECTID       NCESSCH   SURVYEAR STABR  \
# 1      -86.204900  34.262200         2   10000500871  2020-2021    AL
# 7      -86.142000  34.362500         8   10000600872  2020-2021    AL
# 10     -86.319462  34.178658        11   10000600878  2020-2021    AL
# 12     -86.253261  34.534948        13   10000600883  2020-2021    AL
# 15     -86.285900  34.305400        16   10000600987  2020-2021    AL
# ...           ...        ...       ...           ...        ...   ...
# 100698 -66.399500  18.431900    100699  720003002085  2020-2021    PR
# 100704 -64.798638  17.722947    100705  780000200013  2020-2021    VI
# 100709 -64.780456  17.725655    100710  780000200030  2020-2021    VI
# 100711 -64.918749  18.342037    100712  780003000005  2020-2021    VI
# 100712 -64.853909  18.324876    100713  780003000015  2020-2021    VI
#
#           LEAID ST_LEAID                                   LEA_NAME  \
# 1        100005   AL-101                           Albertville City
# 7        100006   AL-048                            Marshall County
# 10       100006   AL-048                            Marshall County
# 12       100006   AL-048                            Marshall County
# 15       100006   AL-048                            Marshall County
# ...         ...      ...                                        ...
# 100698  7200030    PR-01        PUERTO RICO DEPARTMENT OF EDUCATION
# 100704  7800002   VI-002                Saint Croix School District
# 100709  7800002   VI-002                Saint Croix School District
# 100711  7800030   VI-001  Saint Thomas - Saint John School District
# 100712  7800030   VI-001  Saint Thomas - Saint John School District
#
#                                         SCH_NAME  ...  HIALF     HI TRALM  \
# 1                        Albertville High School  ...  371.0  785.0  17.0
# 7                             Asbury High School  ...  160.0  285.0   1.0
# 10                           Douglas High School  ...  119.0  255.0   2.0
# 12                  Kate D Smith DAR High School  ...    5.0   14.0   6.0
# 15                     Marshall Technical School  ...    NaN    NaN   NaN
# ...                                          ...  ...    ...    ...   ...
# 100698        JUAN QUIRINDONGO MORELL (SUPERIOR)  ...  256.0  499.0   NaN
# 100704  ST. CROIX EDUCATIONAL COMPEX HIGH SCHOOL  ...   97.0  183.0   NaN
# 100709                  SAINT CROIX CENTRAL HIGH  ...  142.0  277.0   1.0
# 100711              CHARLOTTE AMALIE HIGH SCHOOL  ...   88.0  170.0   1.0
# 100712            IVANNA EUDORA KEAN HIGH SCHOOL  ...   21.0   57.0   1.0
#
#        TRALF    TR  WHALM  WHALF     WH     LATCOD     LONCOD
# 1       21.0  38.0  368.0  338.0  706.0  34.262200 -86.204900
# 7        2.0   3.0  182.0  146.0  328.0  34.362500 -86.142000
# 10       3.0   5.0  203.0  177.0  380.0  34.178658 -86.319462
# 12       1.0   7.0  225.0  180.0  405.0  34.534948 -86.253261
# 15       NaN   NaN    NaN    NaN    NaN  34.305400 -86.285900
# ...      ...   ...    ...    ...    ...        ...        ...
# 100698   NaN   NaN    NaN    NaN    NaN  18.431900 -66.399500
# 100704   1.0   1.0    4.0    2.0    6.0  17.722947 -64.798638
# 100709   4.0   5.0    4.0    NaN    4.0  17.725655 -64.780456
# 100711   6.0   7.0   11.0   10.0   21.0  18.342037 -64.918749
# 100712   3.0   4.0    2.0    1.0    3.0  18.324876 -64.853909
#
# [23295 rows x 79 columns]

# %%
percent_high=(round(highschool.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME/(pubschool.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME)*100, 3).reset_index())

# %%
percent_high=percent_high.rename(columns={'STABR':'State', 'SCH_NAME':'Percent_High'})

# %%
percent_high
# Out:
#    State  Percent_High
# 0     AK        15.324
# 1     AL        26.235
# 2     AR        27.870
# 3     AS        20.690
# 4     AZ        30.323
# 5     BI        12.644
# 6     CA        21.607
# 7     CO        22.574
# 8     CT        19.680
# 9     DC        17.021
# 10    DE        18.261
# 11    FL        22.170
# 12    GA        19.602
# 13    GU        15.909
# 14    HI        14.576
# 15    IA        25.745
# 16    ID        25.917
# 17    IL        21.852
# 18    IN        21.504
# 19    KS        26.183
# 20    KY        28.851
# 21    LA        20.384
# 22    MA        20.108
# 23    MD        16.890
# 24    ME        19.601
# 25    MI        28.202
# 26    MN        36.310
# 27    MO        26.992
# 28    MP        17.143
# 29    MS        30.326
# 30    MT        20.869
# 31    NC        21.575
# 32    ND        31.073
# 33    NE        24.770
# 34    NH        19.153
# 35    NJ        18.862
# 36    NM        24.718
# 37    NV        19.629
# 38    NY        24.488
# 39    OH        25.510
# 40    OK        26.089
# 41    OR        21.219
# 42    PA        24.289
# 43    PR        23.086
# 44    RI        20.701
# 45    SC        22.656
# 46    SD        27.008
# 47    TN        21.489
# 48    TX        19.436
# 49    UT        17.610
# 50    VA        15.258
# 51    VI        17.391
# 52    VT        20.656
# 53    WA        26.047
# 54    WI        24.889
# 55    WV        22.644
# 56    WY        24.725

# %%
highschool.groupby('STABR').count().sort_values('SCH_NAME', ascending=False)

# %%
midschool=pubschool.loc[pubschool['SCHOOL_LEVEL']=='Middle']

# %%
midschool.groupby('STABR').count().sort_values('SCH_NAME', ascending=False)
# Out:
#           X     Y  OBJECTID  NCESSCH  SURVYEAR  LEAID  ST_LEAID  LEA_NAME  \
# STABR
# TX     1753  1753      1753     1753      1753   1753      1753      1753
# CA     1410  1410      1410     1410      1410   1410      1410      1410
# NY      809   809       809      809       809    809       809       809
# IL      720   720       720      720       720    720       720       720
# OH      659   659       659      659       659    659       659       659
# FL      588   588       588      588       588    588       588       588
# PA      524   524       524      524       524    524       524       524
# MI      508   508       508      508       508    508       508       508
# NC      486   486       486      486       486    486       486       486
# GA      477   477       477      477       477    477       477       477
# NJ      430   430       430      430       430    430       430       430
# WI      403   403       403      403       403    403       403       403
# MO      397   397       397      397       397    397       397       397
# WA      378   378       378      378       378    378       378       378
# OK      365   365       365      365       365    365       365       365
# TN      357   357       357      357       357    357       357       357
# VA      347   347       347      347       347    347       347       347
# IN      331   331       331      331       331    331       331       331
# MA      323   323       323      323       323    323       323       323
# MN      321   321       321      321       321    321       321       321
# CO      288   288       288      288       288    288       288       288
# AL      257   257       257      257       257    257       257       257
# SC      251   251       251      251       251    251       251       251
# IA      250   250       250      250       250    250       250       250
# AZ      232   232       232      232       232    232       232       232
# MD      229   229       229      229       229    229       229       229
# LA      226   226       226      226       226    226       226       226
# MT      225   225       225      225       225    225       225       225
# KS      224   224       224      224       224    224       224       224
# KY      220   220       220      220       220    220       220       220
# AR      209   209       209      209       209    209       209       209
# OR      204   204       204      204       204    204       204       204
# MS      186   186       186      186       186    186       186       186
# CT      179   179       179      179       179    179       179       179
# SD      169   169       169      169       169    169       169       169
# NM      164   164       164      164       164    164       164       164
# UT      141   141       141      141       141    141       141       141
# NE      128   128       128      128       128    128       128       128
# NV      117   117       117      117       117    117       117       117
# ID      114   114       114      114       114    114       114       114
# WV      111   111       111      111       111    111       111       111
# NH      100   100       100      100       100    100       100       100
# PR       94    94        94       94        94     94        94        94
# ME       85    85        85       85        85     85        85        85
# WY       61    61        61       61        61     61        61        61
# RI       59    59        59       59        59     59        59        59
# ND       42    42        42       42        42     42        42        42
# HI       42    42        42       42        42     42        42        42
# DC       41    41        41       41        41     41        41        41
# AK       38    38        38       38        38     38        38        38
# DE       37    37        37       37        37     37        37        37
# VT       26    26        26       26        26     26        26        26
# GU        9     9         9        9         9      9         9         9
# MP        5     5         5        5         5      5         5         5
# BI        5     5         5        5         5      5         5         5
# VI        3     3         3        3         3      3         3         3
#
#        SCH_NAME  LSTREET1  ...  HIALF    HI  TRALM  TRALF    TR  WHALM  WHALF  \
# STABR                      ...
# TX         1753      1753  ...   1753  1753   1753   1753  1753   1753   1753
# CA         1410      1410  ...   1406  1407   1284   1291  1335   1349   1350
# NY          809       809  ...    797   803    672    670   719    789    781
# IL          720       720  ...    653   672    645    639   669    689    686
# OH          659       659  ...    659   659    659    659   659    659    659
# FL          588       588  ...    588   588    588    588   588    588    588
# PA          524       524  ...    524   524    524    524   524    524    524
# MI          508       508  ...    508   508    508    508   508    508    508
# NC          486       486  ...    486   486    486    486   486    486    486
# GA          477       477  ...    477   477    477    477   477    477    477
# NJ          430       430  ...    427   429    380    386   403    424    422
# WI          403       403  ...    376   391    361    363   385    400    400
# MO          397       397  ...    359   378    350    355   369    387    389
# WA          378       378  ...    374   375    364    368   373    378    377
# OK          365       365  ...    354   361    365    365   365    365    364
# TN          357       357  ...    350   354    339    337   347    345    341
# VA          347       347  ...    347   347    347    347   347    347    347
# IN          331       331  ...    325   330    326    325   329    330    329
# MA          323       323  ...    320   322    312    305   318    321    320
# MN          321       321  ...    299   311    295    300   307    309    303
# CO          288       288  ...    287   287    262    264   272    287    286
# AL          257       257  ...    256   256    256    256   256    256    256
# SC          251       251  ...    251   251    251    251   251    251    251
# IA          250       250  ...    240   245    224    219   237    250    250
# AZ          232       232  ...    232   232    232    232   232    232    232
# MD          229       229  ...    224   228    220    219   224    223    226
# LA          226       226  ...    213   219    207    206   218    221    221
# MT          225       225  ...    225   225    225    225   225    225    225
# KS          224       224  ...    217   220    197    199   208    224    224
# KY          220       220  ...    213   220    211    212   218    218    218
# AR          209       209  ...    206   208    187    187   195    207    207
# OR          204       204  ...    204   204    204    204   204    204    204
# MS          186       186  ...    162   172    162    160   170    175    178
# CT          179       179  ...    179   179    175    173   177    179    179
# SD          169       169  ...    169   169    169    169   169    169    169
# NM          164       164  ...    159   161     95     91   109    154    151
# UT          141       141  ...    137   137    128    129   129    137    137
# NE          128       128  ...    128   128    128    128   128    128    128
# NV          117       117  ...    117   117    117    117   117    117    117
# ID          114       114  ...    113   113    113    113   113    113    113
# WV          111       111  ...     87    99    100     99   107    111    111
# NH          100       100  ...     92    98     87     89    95    100    100
# PR           94        94  ...     94    94      0      0     0     14     11
# ME           85        85  ...     74    81     75     78    81     85     85
# WY           61        61  ...     61    61     61     61    61     61     61
# RI           59        59  ...     58    59     59     58    59     59     59
# ND           42        42  ...     38    41     37     38    40     40     40
# HI           42        42  ...     42    42     42     42    42     42     40
# DC           41        41  ...     39    40     20     19    22     18     16
# AK           38        38  ...     38    38     38     38    38     38     38
# DE           37        37  ...     36    37     37     36    37     37     37
# VT           26        26  ...     20    24     19     20    22     26     26
# GU            9         9  ...      8     8      8      8     8      8      8
# MP            5         5  ...      0     0      0      0     0      0      0
# BI            5         5  ...      0     0      0      0     0      0      0
# VI            3         3  ...      3     3      2      0     2      3      3
#
#          WH  LATCOD  LONCOD
# STABR
# TX     1753    1753    1753
# CA     1378    1410    1410
# NY      802     809     809
# IL      694     720     720
# OH      659     659     659
# FL      588     588     588
# PA      524     524     524
# MI      508     508     508
# NC      486     486     486
# GA      477     477     477
# NJ      424     430     430
# WI      401     403     403
# MO      390     397     397
# WA      378     378     378
# OK      365     365     365
# TN      352     357     357
# VA      347     347     347
# IN      330     331     331
# MA      322     323     323
# MN      311     321     321
# CO      288     288     288
# AL      256     257     257
# SC      251     251     251
# IA      250     250     250
# AZ      232     232     232
# MD      226     229     229
# LA      223     226     226
# MT      225     225     225
# KS      224     224     224
# KY      220     220     220
# AR      207     209     209
# OR      204     204     204
# MS      181     186     186
# CT      179     179     179
# SD      169     169     169
# NM      157     164     164
# UT      137     141     141
# NE      128     128     128
# NV      117     117     117
# ID      113     114     114
# WV      111     111     111
# NH      100     100     100
# PR       21      94      94
# ME       85      85      85
# WY       61      61      61
# RI       59      59      59
# ND       40      42      42
# HI       42      42      42
# DC       21      41      41
# AK       38      38      38
# DE       37      37      37
# VT       26      26      26
# GU        8       9       9
# MP        0       5       5
# BI        0       5       5
# VI        3       3       3
#
# [56 rows x 78 columns]

# %%
percent_mid=(round(midschool.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME/(pubschool.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME)*100, 3).reset_index())

# %%
percent_mid=percent_mid.rename(columns={'STABR':'State', 'SCH_NAME':'Percent_mid'})

# %%
percent_mid

# %%
school_perc=percent_elem.merge(percent_high, how='outer', on='State')

# %%
school_perc=school_perc.merge(percent_mid, how='outer', on='State')

# %%
school_perc['Percent_unaccounted']=(100-(school_perc.Percent_elem+school_perc.Percent_High+school_perc.Percent_mid))

# %%
school_perc
# Out:
#    State  Percent_elem  Percent_High  Percent_mid  Percent_unaccounted
# 0     AK        33.792        15.324        7.466               43.418
# 1     AL        45.093        26.235       16.485               12.187
# 2     AR        47.685        27.870       19.352                5.093
# 3     AS        79.310        20.690          NaN                  NaN
# 4     AZ        48.669        30.323        9.355               11.653
# 5     BI        62.069        12.644        2.874               22.413
# 6     CA        57.783        21.607       13.650                6.960
# 7     CO        54.229        22.574       14.946                8.251
# 8     CT        60.340        19.680       17.882                2.098
# 9     DC        60.851        17.021       17.447                4.681
# 10    DE        51.739        18.261       16.087               13.913
# 11    FL        52.144        22.170       13.780               11.906
# 12    GA        56.772        19.602       20.640                2.986
# 13    GU        61.364        15.909       20.455                2.272
# 14    HI        62.373        14.576       14.237                8.814
# 15    IA        52.101        25.745       19.099                3.055
# 16    ID        49.052        25.917       14.412               10.619
# 17    IL        53.490        21.852       16.423                8.235
# 18    IN        55.521        21.504       17.403                5.572
# 19    KS        55.267        26.183       17.099                1.451
# 20    KY        47.258        28.851       14.360                9.531
# 21    LA        53.250        20.384       16.691                9.675
# 22    MA        57.073        20.108       17.507                5.312
# 23    MD        62.562        16.890       16.115                4.433
# 24    ME        58.638        19.601       14.120                7.641
# 25    MI        46.665        28.202       14.298               10.835
# 26    MN        38.749        36.310       12.628               12.313
# 27    MO        49.715        26.992       16.138                7.155
# 28    MP        25.714        17.143       14.286               42.857
# 29    MS        42.418        30.326       17.850                9.406
# 30    MT        51.628        20.869       27.141                0.362
# 31    NC        54.396        21.575       17.802                6.227
# 32    ND        51.224        31.073        7.910                9.793
# 33    NE        49.816        24.770       11.786               13.628
# 34    NH        57.460        19.153       20.161                3.226
# 35    NJ        58.418        18.862       16.758                5.962
# 36    NM        51.580        24.718       18.510                5.192
# 37    NV        56.499        19.629       15.517                8.355
# 38    NY        53.053        24.488       16.746                5.713
# 39    OH        50.340        25.510       18.658                5.492
# 40    OK        52.179        26.089       20.391                1.341
# 41    OR        56.453        21.219       16.152                6.176
# 42    PA        55.556        24.289       17.751                2.404
# 43    PR        60.895        23.086       11.072                4.947
# 44    RI        55.732        20.701       18.790                4.777
# 45    SC        54.062        22.656       19.609                3.673
# 46    SD        45.429        27.008       23.407                4.156
# 47    TN        54.468        21.489       18.989                5.054
# 48    TX        49.741        19.436       18.517               12.306
# 49    UT        56.244        17.610       12.668               13.478
# 50    VA        53.850        15.258       16.291               14.601
# 51    VI        65.217        17.391       13.043                4.349
# 52    VT        68.197        20.656        8.525                2.622
# 53    WA        48.664        26.047       15.078               10.211
# 54    WI        50.000        24.889       17.848                7.263
# 55    WV        57.806        22.644       15.612                3.938
# 56    WY        53.297        24.725       16.758                5.220

# %%
pubschool1920=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Public_School_Characteristics_2019-20.csv')

# %%
pubschool1920.groupby('STABR').count().sort_values('SCH_NAME', ascending=False)
# Out:
#            X      Y  OBJECTID  NCESSCH  SURVYEAR  LEAID  ST_LEAID  LEA_NAME  \
# STABR
# CA     10381  10381     10381    10381     10381  10381     10381     10381
# TX      9425   9425      9425     9425      9425   9425      9425      9425
# NY      4833   4833      4833     4833      4833   4833      4833      4833
# IL      4351   4351      4351     4351      4351   4351      4351      4351
# FL      4244   4244      4244     4244      4244   4244      4244      4244
# MI      3562   3562      3562     3562      3562   3562      3562      3562
# OH      3539   3539      3539     3539      3539   3539      3539      3539
# PA      2960   2960      2960     2960      2960   2960      2960      2960
# NC      2704   2704      2704     2704      2704   2704      2704      2704
# MN      2586   2586      2586     2586      2586   2586      2586      2586
# NJ      2566   2566      2566     2566      2566   2566      2566      2566
# WA      2475   2475      2475     2475      2475   2475      2475      2475
# MO      2456   2456      2456     2456      2456   2456      2456      2456
# AZ      2418   2418      2418     2418      2418   2418      2418      2418
# GA      2311   2311      2311     2311      2311   2311      2311      2311
# WI      2258   2258      2258     2258      2258   2258      2258      2258
# VA      2123   2123      2123     2123      2123   2123      2123      2123
# CO      1920   1920      1920     1920      1920   1920      1920      1920
# IN      1912   1912      1912     1912      1912   1912      1912      1912
# TN      1878   1878      1878     1878      1878   1878      1878      1878
# MA      1847   1847      1847     1847      1847   1847      1847      1847
# OK      1794   1794      1794     1794      1794   1794      1794      1794
# AL      1536   1536      1536     1536      1536   1536      1536      1536
# KY      1536   1536      1536     1536      1536   1536      1536      1536
# MD      1420   1420      1420     1420      1420   1420      1420      1420
# LA      1364   1364      1364     1364      1364   1364      1364      1364
# KS      1311   1311      1311     1311      1311   1311      1311      1311
# IA      1310   1310      1310     1310      1310   1310      1310      1310
# SC      1269   1269      1269     1269      1269   1269      1269      1269
# OR      1255   1255      1255     1255      1255   1255      1255      1255
# UT      1087   1087      1087     1087      1087   1087      1087      1087
# NE      1082   1082      1082     1082      1082   1082      1082      1082
# AR      1077   1077      1077     1077      1077   1077      1077      1077
# MS      1047   1047      1047     1047      1047   1047      1047      1047
# CT      1005   1005      1005     1005      1005   1005      1005      1005
# NM       885    885       885      885       885    885       885       885
# PR       847    847       847      847       847    847       847       847
# MT       828    828       828      828       828    828       828       828
# ID       772    772       772      772       772    772       772       772
# NV       750    750       750      750       750    750       750       750
# WV       725    725       725      725       725    725       725       725
# SD       708    708       708      708       708    708       708       708
# ME       599    599       599      599       599    599       599       599
# AK       506    506       506      506       506    506       506       506
# NH       497    497       497      497       497    497       497       497
# ND       491    491       491      491       491    491       491       491
# WY       360    360       360      360       360    360       360       360
# RI       316    316       316      316       316    316       316       316
# VT       308    308       308      308       308    308       308       308
# HI       295    295       295      295       295    295       295       295
# DC       230    230       230      230       230    230       230       230
# DE       226    226       226      226       226    226       226       226
# BI       174    174       174      174       174    174       174       174
# GU        44     44        44       44        44     44        44        44
# AS        29     29        29       29        29     29        29        29
# VI        23     23        23       23        23     23        23        23
#
#        SCH_NAME  LSTREET1  ...  HIALF     HI  TRALM  TRALF     TR  WHALM  \
# STABR                      ...
# CA        10381     10381  ...  10381  10381  10381  10381  10381  10381
# TX         9425      9425  ...   9425   9425   9425   9425   9425   9425
# NY         4833      4833  ...   4833   4833   4833   4833   4833   4833
# IL         4351      4351  ...   4351   4351   4351   4351   4351   4351
# FL         4244      4244  ...   4244   4244   4244   4244   4244   4244
# MI         3562      3562  ...   3562   3562   3562   3562   3562   3562
# OH         3539      3539  ...   3539   3539   3539   3539   3539   3539
# PA         2960      2960  ...   2960   2960   2960   2960   2960   2960
# NC         2704      2704  ...   2704   2704   2704   2704   2704   2704
# MN         2586      2586  ...   2586   2586   2586   2586   2586   2586
# NJ         2566      2566  ...   2566   2566   2566   2566   2566   2566
# WA         2475      2475  ...   2475   2475   2475   2475   2475   2475
# MO         2456      2456  ...   2456   2456   2456   2456   2456   2456
# AZ         2418      2418  ...   2418   2418   2418   2418   2418   2418
# GA         2311      2311  ...   2311   2311   2311   2311   2311   2311
# WI         2258      2258  ...   2258   2258   2258   2258   2258   2258
# VA         2123      2123  ...   2123   2123   2123   2123   2123   2123
# CO         1920      1920  ...   1920   1920   1920   1920   1920   1920
# IN         1912      1912  ...   1912   1912   1912   1912   1912   1912
# TN         1878      1878  ...   1878   1878   1878   1878   1878   1878
# MA         1847      1847  ...   1847   1847   1847   1847   1847   1847
# OK         1794      1794  ...   1794   1794   1794   1794   1794   1794
# AL         1536      1536  ...   1536   1536   1536   1536   1536   1536
# KY         1536      1535  ...   1536   1536   1536   1536   1536   1536
# MD         1420      1420  ...   1420   1420   1420   1420   1420   1420
# LA         1364      1364  ...   1364   1364   1364   1364   1364   1364
# KS         1311      1311  ...   1311   1311   1311   1311   1311   1311
# IA         1310      1310  ...   1310   1310   1310   1310   1310   1310
# SC         1269      1269  ...   1269   1269   1269   1269   1269   1269
# OR         1255      1255  ...   1255   1255   1255   1255   1255   1255
# UT         1087      1087  ...   1087   1087   1087   1087   1087   1087
# NE         1082      1082  ...   1082   1082   1082   1082   1082   1082
# AR         1077      1077  ...   1077   1077   1077   1077   1077   1077
# MS         1047      1047  ...   1047   1047   1047   1047   1047   1047
# CT         1005      1005  ...   1005   1005   1005   1005   1005   1005
# NM          885       885  ...    885    885    885    885    885    885
# PR          847       847  ...    847    847    847    847    847    847
# MT          828       828  ...    828    828    828    828    828    828
# ID          772       772  ...    772    772    772    772    772    772
# NV          750       750  ...    750    750    750    750    750    750
# WV          725       725  ...    725    725    725    725    725    725
# SD          708       708  ...    708    708    708    708    708    708
# ME          599       599  ...    599    599    599    599    599    599
# AK          506       506  ...    506    506    506    506    506    506
# NH          497       497  ...    497    497    497    497    497    497
# ND          491       491  ...    491    491    491    491    491    491
# WY          360       360  ...    360    360    360    360    360    360
# RI          316       316  ...    316    316    316    316    316    316
# VT          308       308  ...    308    308    308    308    308    308
# HI          295       295  ...    295    295    295    295    295    295
# DC          230       230  ...    230    230    230    230    230    230
# DE          226       224  ...    226    226    226    226    226    226
# BI          174       174  ...    174    174    174    174    174    174
# GU           44        44  ...     44     44     44     44     44     44
# AS           29        29  ...     29     29     29     29     29     29
# VI           23        23  ...     23     23     23     23     23     23
#
#        WHALF     WH  LATCOD  LONCOD
# STABR
# CA     10381  10381   10381   10381
# TX      9425   9425    9425    9425
# NY      4833   4833    4833    4833
# IL      4351   4351    4351    4351
# FL      4244   4244    4244    4244
# MI      3562   3562    3562    3562
# OH      3539   3539    3539    3539
# PA      2960   2960    2960    2960
# NC      2704   2704    2704    2704
# MN      2586   2586    2586    2586
# NJ      2566   2566    2566    2566
# WA      2475   2475    2475    2475
# MO      2456   2456    2456    2456
# AZ      2418   2418    2418    2418
# GA      2311   2311    2311    2311
# WI      2258   2258    2258    2258
# VA      2123   2123    2123    2123
# CO      1920   1920    1920    1920
# IN      1912   1912    1912    1912
# TN      1878   1878    1878    1878
# MA      1847   1847    1847    1847
# OK      1794   1794    1794    1794
# AL      1536   1536    1536    1536
# KY      1536   1536    1536    1536
# MD      1420   1420    1420    1420
# LA      1364   1364    1364    1364
# KS      1311   1311    1311    1311
# IA      1310   1310    1310    1310
# SC      1269   1269    1269    1269
# OR      1255   1255    1255    1255
# UT      1087   1087    1087    1087
# NE      1082   1082    1082    1082
# AR      1077   1077    1077    1077
# MS      1047   1047    1047    1047
# CT      1005   1005    1005    1005
# NM       885    885     885     885
# PR       847    847     847     847
# MT       828    828     828     828
# ID       772    772     772     772
# NV       750    750     750     750
# WV       725    725     725     725
# SD       708    708     708     708
# ME       599    599     599     599
# AK       506    506     506     506
# NH       497    497     497     497
# ND       491    491     491     491
# WY       360    360     360     360
# RI       316    316     316     316
# VT       308    308     308     308
# HI       295    295     295     295
# DC       230    230     230     230
# DE       226    226     226     226
# BI       174    174     174     174
# GU        44     44      44      44
# AS        29     29      29      29
# VI        23     23      23      23
#
# [56 rows x 78 columns]

# %%
elem_schools_1920=pubschool1920.loc[pubschool1920['SCHOOL_LEVEL']=='Elementary']

# %%
percent_elem_1920=(round(elem_schools_1920.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME/(pubschool1920.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME)*100, 3).reset_index())

# %%
percent_elem_1920=percent_elem_1920.rename(columns={'STABR':'State', 'SCH_NAME':'Percent_elem'})

# %%
mid_schools_1920=pubschool1920.loc[pubschool1920['SCHOOL_LEVEL']=='Middle']

# %%
percent_mid_1920=(round(mid_schools_1920.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME/(pubschool1920.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME)*100, 3).reset_index())

# %%
percent_mid_1920=percent_mid_1920.rename(columns={'STABR':'State','SCH_NAME':'Percent_mid'})

# %%
hi_schools_1920=pubschool1920.loc[pubschool1920['SCHOOL_LEVEL']=='High']

# %%
percent_hi_1920=(round(hi_schools_1920.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME/(pubschool1920.groupby('STABR').count().sort_values('SCH_NAME', ascending=False).SCH_NAME)*100, 3).reset_index())

# %%
percent_hi_1920=percent_hi_1920.rename(columns={'STABR':'State', 'SCH_NAME':'Percent_high'})

# %%
schools1920=percent_elem_1920.merge(percent_mid_1920, how='inner', on='State')

# %%
schools1920=schools1920.merge(percent_hi_1920, how='inner', on='State')

# %%
schools1920['Percent_unaccounted']=(100-(schools1920.Percent_elem+schools1920.Percent_high+schools1920.Percent_mid))

# %%
tn_scores=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/TN_SCORES.csv')

# %%
tn_scores
# Out:
#      district_number                district_name  \
# 0                 10                     Anderson
# 1                 10                     Anderson
# 2                 10                     Anderson
# 3                 10                     Anderson
# 4                 10                     Anderson
# ..               ...                          ...
# 590              985  Achievement School District
# 591              985  Achievement School District
# 592              985  Achievement School District
# 593              985  Achievement School District
# 594              985  Achievement School District
#
#                            subgroup  valid_tests participation_rate  \
# 0                      All Students          527                100
# 1    Black/Hispanic/Native American           17                100
# 2        Economically Disadvantaged          189                 99
# 3                  English Learners            3                  *
# 4        Students with Disabilities           76                100
# ..                              ...          ...                ...
# 590                    All Students          294                 83
# 591  Black/Hispanic/Native American          292                 83
# 592      Economically Disadvantaged          244                 83
# 593                English Learners            7                  *
# 594      Students with Disabilities           40                 67
#
#     average_english_score average_math_score average_reading_score  \
# 0                      19               18.7                 19.90
# 1                      18               17.8                  17.5
# 2                   17.10               17.2                  18.6
# 3                       *                  *                     *
# 4                    12.5               15.5                  14.5
# ..                    ...                ...                   ...
# 590                  13.4               15.4                  14.8
# 591                  13.4               15.4                  14.9
# 592                  13.2               15.2                  14.6
# 593                     *                  *                     *
# 594                    11               14.6                    13
#
#     average_science_score average_composite_score number_scoring_21_or_higher  \
# 0                   19.60                    19.5                         198
# 1                    18.3                    17.9                           5
# 2                   18.10                    17.9                          43
# 3                       *                       *                           *
# 4                    15.1                    14.6                           2
# ..                    ...                     ...                         ...
# 590                    15                    14.8                          14
# 591                    15                    14.8                          14
# 592                  14.7                    14.6                           9
# 593                     *                       *                           *
# 594                  13.1                      13                          **
#
#     percent_scoring_21_or_higher number_scoring_below_19  \
# 0                           37.6                     254
# 1                           29.4                      10
# 2                           22.8                     118
# 3                              *                       *
# 4                            2.6                      71
# ..                           ...                     ...
# 590                          4.8                     261
# 591                          4.8                     259
# 592                          3.7                     221
# 593                            *                       *
# 594                           **                      **
#
#     percent_scoring_below_19
# 0                       48.2
# 1                       58.8
# 2                       62.4
# 3                          *
# 4                       93.4
# ..                       ...
# 590                     88.8
# 591                     88.7
# 592                     90.6
# 593                        *
# 594                       **
#
# [595 rows x 14 columns]

# %%
tn_scores['district_name']=tn_scores['district_name'].str.replace(' County', '')

# %%
tn_scores['district_name']=tn_scores['district_name'].str.replace(' Co Sp Dist', '')

# %%
tn_scores['district_name']=tn_scores['district_name'].str.replace(' Public Schools', '')

# %%
tn_scores.district_name.unique()
# Out:
# array(['Anderson', 'Oak Ridge', 'Bedford', 'Benton', 'Bledsoe', 'Blount',
#        'Alcoa', 'Maryville', 'Bradley', 'Cleveland', 'Campbell', 'Cannon',
#        'Hollow Rock - Bruceton', 'Huntingdon Special School District',
#        'McKenzie', 'South Carroll', 'West Carroll Sp Dist', 'Carter',
#        'Elizabethton', 'Cheatham', 'Chester', 'Claiborne', 'Clay',
#        'Cocke', 'Coffee', 'Tullahoma', 'Crockett', 'Cumberland',
#        'Davidson', 'Decatur', 'DeKalb', 'Dickson', 'Dyer', 'Dyersburg',
#        'Fayette', 'Fentress', 'Franklin', 'Humboldt City Schools',
#        'Milan', 'Trenton', 'Bradford', 'Gibson', 'Giles', 'Grainger',
#        'Greene', 'Greeneville', 'Grundy', 'Hamblen', 'Hamilton',
#        'Hancock', 'Hardeman Schools', 'Hardin', 'Hawkins', 'Haywood',
#        'Henderson', 'Henry', 'Hickman', 'Houston', 'Humphreys', 'Jackson',
#        'Jefferson', 'Johnson', 'Knox', 'Lake', 'Lauderdale', 'Lawrence',
#        'Lewis', 'Lincoln', 'Fayetteville', 'Loudon', 'Lenoir City',
#        'McMinn', 'McNairy', 'Macon', 'Madison', 'Marion', 'Richard City',
#        'Marshall', 'Maury', 'Meigs', 'Monroe', 'Montgomery', 'Moore',
#        'Morgan', 'Obion', 'Union City', 'Overton', 'Perry', 'Pickett',
#        'Polk', 'Putnam', 'Rhea', 'Roane', 'Robertson', 'Rutherford',
#        'Scott', 'Oneida', 'Sequatchie', 'Sevier', 'Shelby', 'Arlington',
#        'Bartlett', 'Collierville', 'Germantown',
#        'Millington Municipal Schools', 'Smith', 'Stewart', 'Sullivan',
#        'Bristol', 'Kingsport', 'Sumner', 'Tipton', 'Trousdale', 'Unicoi',
#        'Union', 'Van Buren', 'Warren', 'Washington', 'Johnson City',
#        'Wayne', 'Weakley', 'White', 'Williamson', 'Wilson',
#        'Alvin C York Institute', 'Tennessee School for Blind',
#        'Tennessee School for the Deaf',
#        "Department Of Children's Services Education Division",
#        'Achievement School District'], dtype=object)

# %%
all_tn_scores=tn_scores.loc[tn_scores['subgroup']=='All Students']

# %%
all_tn_scores=all_tn_scores[['district_name', 'average_math_score', 'average_reading_score', 'average_composite_score']]

# %%
places_data=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/places_data.csv')

# %%
tn_stroke=places_data.loc[(places_data['StateDesc']=='Tennessee')&(places_data['Measure']=='Stroke among adults aged >=18 years')&(places_data['Data_Value_Type']=='Crude prevalence')]

# %%
tn_stroke=tn_stroke[['Year', 'StateAbbr', 'LocationName', 'Data_Value', 'Geolocatioin']].sort_values('LocationName')

# %%
tn_stroke
# Out:
#         Year StateAbbr LocationName  Data_Value  \
# 136114  2018        TN     Anderson         4.2
# 136170  2018        TN      Bedford         4.1
# 136226  2018        TN       Benton         5.4
# 136282  2018        TN      Bledsoe         4.6
# 136337  2018        TN       Blount         3.9
# ...      ...       ...          ...         ...
# 141150  2018        TN        Wayne         4.5
# 141206  2018        TN      Weakley         4.1
# 141262  2018        TN        White         4.8
# 141318  2018        TN   Williamson         2.5
# 141374  2018        TN       Wilson         3.2
#
#                             Geolocatioin
# 136114  POINT (-84.19889754 36.11848968)
# 136170   POINT (-86.4596514 35.51433533)
# 136226  POINT (-88.06825884 36.06933865)
# 136282  POINT (-85.20485133 35.59675049)
# 136337  POINT (-83.92474231 35.68738201)
# ...                                  ...
# 141150  POINT (-87.78807284 35.24007822)
# 141206   POINT (-88.71784069 36.2978994)
# 141262  POINT (-85.45549182 35.92648768)
# 141318  POINT (-86.89816665 35.89431575)
# 141374  POINT (-86.29704624 36.15405666)
#
# [95 rows x 5 columns]

# %%
tn_insurance=places_data.loc[(places_data['StateDesc']=='Tennessee')&(places_data['Measure']=='Current lack of health insurance among adults aged 18-64 years')&(places_data['Data_Value_Type']=='Crude prevalence')]

# %%
tn_insurance[['Year', 'StateAbbr', 'LocationName', 'Data_Value', 'Geolocatioin']]
# Out:
#         Year StateAbbr LocationName  Data_Value  \
# 136062  2018        TN     Anderson        14.6
# 136118  2018        TN      Bedford        18.6
# 136174  2018        TN       Benton        17.4
# 136230  2018        TN      Bledsoe        18.4
# 136286  2018        TN       Blount        13.8
# ...      ...       ...          ...         ...
# 141098  2018        TN        Wayne        18.0
# 141154  2018        TN      Weakley        16.0
# 141210  2018        TN        White        17.2
# 141266  2018        TN   Williamson         9.4
# 141322  2018        TN       Wilson        12.8
#
#                             Geolocatioin
# 136062  POINT (-84.19889754 36.11848968)
# 136118   POINT (-86.4596514 35.51433533)
# 136174  POINT (-88.06825884 36.06933865)
# 136230  POINT (-85.20485133 35.59675049)
# 136286  POINT (-83.92474231 35.68738201)
# ...                                  ...
# 141098  POINT (-87.78807284 35.24007822)
# 141154   POINT (-88.71784069 36.2978994)
# 141210  POINT (-85.45549182 35.92648768)
# 141266  POINT (-86.89816665 35.89431575)
# 141322  POINT (-86.29704624 36.15405666)
#
# [95 rows x 5 columns]

# %%
tn_diabetes=places_data.loc[(places_data['StateDesc']=='Tennessee')&(places_data['Measure']=='Diagnosed diabetes among adults aged >=18 years')&(places_data['Data_Value_Type']=='Crude prevalence')]

# %%
tn_diabetes=tn_diabetes[['LocationName', 'Data_Value']]

# %%
tn_diabetes=tn_diabetes.rename(columns={'Data_Value':'Percent_diabetes'})

# %%
tn_heart=places_data.loc[(places_data['StateDesc']=='Tennessee')&(places_data['Measure']=='Coronary heart disease among adults aged >=18 years')&(places_data['Data_Value_Type']=='Crude prevalence')]

# %%
tn_heart=tn_heart[['LocationName', 'Data_Value']]

# %%
tn_heart=tn_heart.rename(columns={'Data_Value':'Percent_heart'})

# %%
tn_bigdf=pd.DataFrame()

# %%
tn_bigdf=tn_stroke.merge(tn_heart, how='inner', on='LocationName')

# %%
tn_bigdf=tn_bigdf.rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_stroke', 'Geolocatioin':'Geolocation'})

# %%
tn_bigdf=tn_bigdf.merge(tn_diabetes, how='inner', on='LocationName')

# %%
tn_bigdf=tn_bigdf.merge(all_tn_scores, how='left', left_on='LocationName', right_on='district_name')

# %%
tn_bigdf.average_math_score=tn_bigdf.average_math_score.astype(float)

# %%
tn_bigdf.average_reading_score=tn_bigdf.average_reading_score.astype(float)

# %%
tn_bigdf.average_composite_score=tn_bigdf.average_composite_score.astype(float)

# %%
tn_bigdf.dtypes
# Out:
# Year                         int64
# State                       object
# LocationName                object
# Percent_stroke             float64
# Geolocation                 object
# Percent_heart              float64
# Percent_diabetes           float64
# district_name               object
# average_math_score         float64
# average_reading_score      float64
# average_composite_score    float64
# dtype: object

# %%
tn_bigdf.corr()
# Out:
#                          Year  Percent_stroke  Percent_heart  \
# Year                      NaN             NaN            NaN
# Percent_stroke            NaN        1.000000       0.945274
# Percent_heart             NaN        0.945274       1.000000
# Percent_diabetes          NaN        0.978517       0.887740
# average_math_score        NaN       -0.543118      -0.433227
# average_reading_score     NaN       -0.562348      -0.443777
# average_composite_score   NaN       -0.551419      -0.436255
#
#                          Percent_diabetes  average_math_score  \
# Year                                  NaN                 NaN
# Percent_stroke                   0.978517           -0.543118
# Percent_heart                    0.887740           -0.433227
# Percent_diabetes                 1.000000           -0.570942
# average_math_score              -0.570942            1.000000
# average_reading_score           -0.588575            0.927644
# average_composite_score         -0.579856            0.971759
#
#                          average_reading_score  average_composite_score
# Year                                       NaN                      NaN
# Percent_stroke                       -0.562348                -0.551419
# Percent_heart                        -0.443777                -0.436255
# Percent_diabetes                     -0.588575                -0.579856
# average_math_score                    0.927644                 0.971759
# average_reading_score                 1.000000                 0.975586
# average_composite_score               0.975586                 1.000000

# %%
tn_bigdf.sort_values('Percent_stroke', ascending=False).head(5)
# Out:
#     Year State LocationName  Percent_stroke                       Geolocation  \
# 13  2018    TN         Clay             5.9   POINT (-85.54311311 36.5507229)
# 37  2018    TN      Haywood             5.6  POINT (-89.28413484 35.58311089)
# 68  2018    TN      Pickett             5.5   POINT (-85.07385942 36.5582716)
# 67  2018    TN        Perry             5.5   POINT (-87.8591474 35.64268858)
# 87  2018    TN    Van Buren             5.4  POINT (-85.45199428 35.69588592)
#
#     Percent_heart  Percent_diabetes district_name  average_math_score  \
# 13           13.1              18.2          Clay                18.5
# 37           10.0              19.0       Haywood                16.7
# 68           12.6              16.8       Pickett                19.3
# 67           12.1              17.1         Perry                16.9
# 87           12.1              17.1     Van Buren                18.5
#
#     average_reading_score  average_composite_score
# 13                   18.5                     18.9
# 37                   17.5                     17.2
# 68                   20.6                     20.4
# 67                   18.0                     17.3
# 87                   19.9                     18.9

# %%
tn_bigdf.sort_values('Percent_stroke', ascending=False).tail(5)
# Out:
#     Year State LocationName  Percent_stroke                       Geolocation  \
# 18  2018    TN     Davidson             3.2   POINT (-86.78482949 36.1695308)
# 94  2018    TN       Wilson             3.2  POINT (-86.29704624 36.15405666)
# 62  2018    TN   Montgomery             2.8  POINT (-87.38312934 36.49670228)
# 74  2018    TN   Rutherford             2.8    POINT (-86.41636678 35.843149)
# 93  2018    TN   Williamson             2.5  POINT (-86.89816665 35.89431575)
#
#     Percent_heart  Percent_diabetes district_name  average_math_score  \
# 18            6.1              10.6      Davidson                18.1
# 94            6.9              11.0        Wilson                19.7
# 62            5.6              10.8    Montgomery                19.4
# 74            5.8              10.3    Rutherford                19.9
# 93            5.6               9.0    Williamson                24.3
#
#     average_reading_score  average_composite_score
# 18                   19.0                     18.5
# 94                   21.5                     20.9
# 62                   20.9                     20.1
# 74                   21.2                     20.8
# 93                   26.0                     25.3

# %%
tn_bigdf.to_csv('tn_data.csv')

# %%
prev_data=places_data.loc[places_data['Category']=='Prevention']

# %%
prev_data.loc[prev_data['StateDesc']=='Tennessee']

# %%
prev_data.loc[prev_data['StateDesc']=='Tennessee'].Measure.unique()

# %%
uninsured=prev_data.loc[(prev_data['Measure']=='Current lack of health insurance among adults aged 18-64 years')&(prev_data['Data_Value_Type']=='Crude prevalence')]

# %%
avg_uninsured_percent=pd.DataFrame()

# %%
state_list=uninsured.StateDesc.unique().tolist()

# %%
for i in state_list:
    avg_uninsured_percent=avg_uninsured_percent.append(uninsured.loc[(uninsured['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())

# %%
avg_uninsured_percent=avg_uninsured_percent.sort_values('StateAbbr')

# %%
avg_uninsured_percent=avg_uninsured_percent.reset_index().rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_uninsured'})

# %%
avg_uninsured_percent
# Out:
#    State  Percent_uninsured
# 0     AK          14.155172
# 1     AL          16.647761
# 2     AR          14.853333
# 3     AZ          16.680000
# 4     CA          13.824138
# 5     CO          14.493750
# 6     CT           9.000000
# 7     DC           8.500000
# 8     DE          14.466667
# 9     FL          23.131343
# 10    GA          23.747799
# 11    HI          10.840000
# 12    IA          10.318182
# 13    ID          17.870455
# 14    IL          12.984314
# 15    IN          13.575000
# 16    KS          16.076190
# 17    KY          10.916667
# 18    LA          15.228125
# 19    MA           8.550000
# 20    MD           9.837500
# 21    ME          14.031250
# 22    MI           9.939759
# 23    MN          10.681609
# 24    MO          16.144348
# 25    MS          20.975610
# 26    MT          12.875000
# 27    NC          18.949000
# 28    ND          11.160377
# 29    NE          12.668817
# 30    NH          10.330000
# 31    NJ          13.457143
# 32    NM          15.087879
# 33    NV          14.517647
# 34    NY          12.006452
# 35    OH           9.845455
# 36    OK          18.009091
# 37    OR          13.411111
# 38    PA          10.086567
# 39    RI           8.540000
# 40    SC          19.019565
# 41    SD          13.057576
# 42    TN          16.448421
# 43    TX          28.470866
# 44    US          12.200000
# 45    UT          14.813793
# 46    VA          16.072932
# 47    VT           9.742857
# 48    WA          12.028205
# 49    WI          11.347222
# 50    WV          11.958182
# 51    WY          15.586957

# %%
health_data=places_data.loc[places_data['Category']=='Health Outcomes']

# %%
health_data.Measure.unique()

# %%
health_data

# %%
stroke_data=health_data.loc[health_data['Measure']=='Stroke among adults aged >=18 years']

# %%
stroke_data.loc[(stroke_data['StateDesc']=='Kansas')&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean()
# Out:
#            Data_Value
# StateAbbr
# KS            3.86381

# %%
avg_stroke_percent=pd.DataFrame()

# %%
for i in state_list:
    avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2180590446.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_stroke_percent=avg_stroke_percent.append(stroke_data.loc[(stroke_data['StateDesc']==i)&(stroke_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())

# %%
avg_stroke_percent=avg_stroke_percent.sort_values('StateAbbr')

# %%
avg_stroke_percent=avg_stroke_percent.reset_index().rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_stroke'})

# %%
diabetes_data=health_data.loc[health_data['Measure']=='Diagnosed diabetes among adults aged >=18 years']

# %%
avg_diabetes_percent=pd.DataFrame()

# %%
for i in state_list:
    avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\4042673178.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_diabetes_percent=avg_diabetes_percent.append(diabetes_data.loc[(diabetes_data['StateDesc']==i)&(diabetes_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())

# %%
avg_diabetes_percent=avg_diabetes_percent.sort_values('StateAbbr')

# %%
avg_diabetes_percent=avg_diabetes_percent.reset_index().rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_Diabetes'})

# %%
'Coronary heart disease among adults aged >=18 years'

# %%
heart_data=health_data.loc[health_data['Measure']=='Coronary heart disease among adults aged >=18 years']

# %%
avg_heart_percent=pd.DataFrame()

# %%
for i in state_list:
    avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3993710914.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   avg_heart_percent=avg_heart_percent.append(heart_data.loc[(heart_data['StateDesc']==i)&(heart_data['Data_Value_Type']=='Crude prevalence'), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())

# %%
avg_heart_percent=avg_heart_percent.sort_values('StateAbbr')

# %%
avg_heart_percent=avg_heart_percent.reset_index().rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_heart'})

# %%
mid_health=avg_stroke_percent.merge(avg_diabetes_percent, how='inner', on='State')

# %%
health_metrics=mid_health.merge(avg_heart_percent, how='inner', on='State')

# %%
health_metrics=health_metrics.merge(avg_uninsured_percent, how='inner', on='State')

# %%
big_df=health_metrics.merge(schools1920, how='inner', on='State')

# %%
math_2019_4=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Math_2019_4.csv')

# %%
math_2019_4=math_2019_4.rename(columns={'Jurisdiction':'State', 'MN':'avg_score_math_4', 'SigDiff':'diff_math_4', 'AB':'math_AB_4','AP':'math_AP_4'})

# %%
math_2019_4=math_2019_4.drop(columns=['SigSymbol'])

# %%
reading_19_4=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Reading_2019_4.csv')

# %%
reading_19_4=reading_19_4.rename(columns={'jurisdiction':'State', 'avg_score':'avg_score_read_4', 'Diff_NP':'diff_read_4', 'At_or_above_B':'read_AB_4','At_or_above_P':'read_AP_4'})

# %%
reading_19_4=reading_19_4.drop(columns=['SigSymbol'])

# %%
scores_2019=reading_19_4.merge(math_2019_4, how='inner', on='State')

# %%
reading_19_8=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Reading_2019_8.csv')

# %%
reading_19_8=reading_19_8.drop(columns=['SigSymbol'])

# %%
math_19_8=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Math_2019_8.csv')

# %%
math_19_8=math_19_8.drop(columns=['SigSymbol'])

# %%
scores_2019=scores_2019.merge(reading_19_8, how='inner', on='State')

# %%
scores_2019=scores_2019.merge(math_19_8, how='inner', on='State')

# %%
big_df=big_df.merge(scores_2019, how='inner', on='State')

# %%
big_df=big_df.merge(ado_mmr_2018_f, how='inner', on='State')

# %%
big_df=big_df.merge(pne_vax_2018_f, how='inner', on='State')

# %%
big_df=big_df.merge(hpv_vax_2018_f, how='inner', on='State')

# %%
big_df=big_df.rename(columns={'avg_score_read':'avg_score_read_4th', 'diff_read':'diff_read_4th', 'read_AB':'read_AB_4th', 'read_AP':'read_AP_4th', 'avg_score_math':'avg_score_math_4th', 'diff_math':'diff_math_4th', 'math_AB':'math_AB_4th', 'math_AP':'math_AP_4th'})

# %%
big_df=big_df.merge(hepb_vax_2018_f, how='inner', on='State')

# %%
big_df[['avg_score_read_4', 'avg_score_read_8th']] = big_df[['avg_score_read_4', 'avg_score_read_8th']].apply(pd.to_numeric)

# %%
big_df.dtypes
# Out:
# State                       object
# Percent_stroke             float64
# Percent_Diabetes           float64
# Percent_heart              float64
# Percent_uninsured          float64
# Percent_elem               float64
# Percent_mid                float64
# Percent_high               float64
# Percent_unaccounted        float64
# avg_score_read_4             int64
# diff_read_4                 object
# read_AB_4                   object
# read_AP_4                   object
# avg_score_math_4             int64
# diff_math_4                  int64
# math_AB_4                    int64
# math_AP_4                    int64
# avg_score_read_8th           int64
# diff_read_8th               object
# read_AB_8th                 object
# read_AP_8th                 object
# avg_math_score_8th           int64
# diff_math_8th                int64
# math_AB_8th                  int64
# math_AP_8th                  int64
# Percentage_MMR             float64
# Percentage_HPV             float64
# Percentage_HepB            float64
# Percentage_Pneumococcal    float64
# dtype: object

# %%
big_df.corr()
# Out:
#                          Percent_stroke  Percent_Diabetes  Percent_heart  \
# Percent_stroke                 1.000000          0.923124       0.846514
# Percent_Diabetes               0.923124          1.000000       0.844281
# Percent_heart                  0.846514          0.844281       1.000000
# Percent_uninsured              0.586196          0.604093       0.420696
# Percent_elem                  -0.378623         -0.308079      -0.349970
# Percent_mid                    0.145763          0.170186       0.109733
# Percent_high                   0.244968          0.138328       0.331877
# Percent_unaccounted            0.099451          0.095038       0.030907
# avg_score_read_4              -0.481608         -0.478209      -0.296196
# avg_score_math_4              -0.442288         -0.432893      -0.318484
# diff_math_4                   -0.442288         -0.432893      -0.318484
# math_AB_4                     -0.290533         -0.287130      -0.132745
# math_AP_4                     -0.491417         -0.495988      -0.341427
# avg_score_read_8th            -0.502849         -0.487345      -0.251862
# avg_math_score_8th            -0.517325         -0.532908      -0.308270
# diff_math_8th                 -0.513597         -0.528797      -0.307402
# math_AB_8th                   -0.426976         -0.470819      -0.193489
# math_AP_8th                   -0.574154         -0.590890      -0.386344
# Percentage_MMR                -0.223543         -0.301477      -0.321120
# Percentage_HPV                -0.602543         -0.622127      -0.570962
# Percentage_HepB               -0.255445         -0.287048      -0.276902
# Percentage_Pneumococcal       -0.091611         -0.130176       0.075005
#
#                          Percent_uninsured  Percent_elem  Percent_mid  \
# Percent_stroke                    0.586196     -0.378623     0.145763
# Percent_Diabetes                  0.604093     -0.308079     0.170186
# Percent_heart                     0.420696     -0.349970     0.109733
# Percent_uninsured                 1.000000     -0.244132     0.132257
# Percent_elem                     -0.244132      1.000000     0.048781
# Percent_mid                       0.132257      0.048781     1.000000
# Percent_high                      0.021645     -0.516654    -0.101765
# Percent_unaccounted               0.139602     -0.603237    -0.544030
# avg_score_read_4                 -0.191688      0.322622     0.122162
# avg_score_math_4                 -0.008104      0.090156     0.033307
# diff_math_4                      -0.008104      0.090156     0.033307
# math_AB_4                         0.076232      0.024599     0.077189
# math_AP_4                        -0.100266      0.054646     0.013600
# avg_score_read_8th               -0.319723      0.304278     0.060038
# avg_math_score_8th               -0.235292      0.097688    -0.010932
# diff_math_8th                    -0.227701      0.099677    -0.006951
# math_AB_8th                      -0.193791      0.053263     0.001001
# math_AP_8th                      -0.304735      0.093498    -0.028786
# Percentage_MMR                   -0.392323      0.151131     0.093196
# Percentage_HPV                   -0.619117      0.345207    -0.126393
# Percentage_HepB                  -0.425060      0.264140     0.028612
# Percentage_Pneumococcal          -0.210458      0.130669     0.201024
#
#                          Percent_high  Percent_unaccounted  avg_score_read_4  \
# Percent_stroke               0.244968             0.099451         -0.481608
# Percent_Diabetes             0.138328             0.095038         -0.478209
# Percent_heart                0.331877             0.030907         -0.296196
# Percent_uninsured            0.021645             0.139602         -0.191688
# Percent_elem                -0.516654            -0.603237          0.322622
# Percent_mid                 -0.101765            -0.544030          0.122162
# Percent_high                 1.000000            -0.168014          0.028865
# Percent_unaccounted         -0.168014             1.000000         -0.394956
# avg_score_read_4             0.028865            -0.394956          1.000000
# avg_score_math_4             0.052861            -0.141877          0.864610
# diff_math_4                  0.052861            -0.141877          0.864610
# math_AB_4                    0.106620            -0.143394          0.815155
# math_AP_4                    0.060172            -0.102320          0.852829
# avg_score_read_8th           0.025823            -0.340013          0.854972
# avg_math_score_8th           0.139428            -0.185549          0.814855
# diff_math_8th                0.137111            -0.188044          0.814526
# math_AB_8th                  0.167858            -0.170706          0.780561
# math_AP_8th                  0.095045            -0.139717          0.788724
# Percentage_MMR              -0.027854            -0.174245          0.307004
# Percentage_HPV              -0.152669            -0.144846          0.211994
# Percentage_HepB             -0.017600            -0.249694          0.391244
# Percentage_Pneumococcal      0.244440            -0.412610          0.292301
#
#                          avg_score_math_4  ...  math_AP_4  avg_score_read_8th  \
# Percent_stroke                  -0.442288  ...  -0.491417           -0.502849
# Percent_Diabetes                -0.432893  ...  -0.495988           -0.487345
# Percent_heart                   -0.318484  ...  -0.341427           -0.251862
# Percent_uninsured               -0.008104  ...  -0.100266           -0.319723
# Percent_elem                     0.090156  ...   0.054646            0.304278
# Percent_mid                      0.033307  ...   0.013600            0.060038
# Percent_high                     0.052861  ...   0.060172            0.025823
# Percent_unaccounted             -0.141877  ...  -0.102320           -0.340013
# avg_score_read_4                 0.864610  ...   0.852829            0.854972
# avg_score_math_4                 1.000000  ...   0.981501            0.694399
# diff_math_4                      1.000000  ...   0.981501            0.694399
# math_AB_4                        0.938497  ...   0.903280            0.627141
# math_AP_4                        0.981501  ...   1.000000            0.721334
# avg_score_read_8th               0.694399  ...   0.721334            1.000000
# avg_math_score_8th               0.827665  ...   0.853256            0.889547
# diff_math_8th                    0.827106  ...   0.851531            0.890154
# math_AB_8th                      0.807694  ...   0.831359            0.849045
# math_AP_8th                      0.798052  ...   0.836866            0.871078
# Percentage_MMR                   0.257225  ...   0.297041            0.325594
# Percentage_HPV                   0.145852  ...   0.176525            0.208636
# Percentage_HepB                  0.281887  ...   0.312506            0.433807
# Percentage_Pneumococcal          0.217523  ...   0.214281            0.376926
#
#                          avg_math_score_8th  diff_math_8th  math_AB_8th  \
# Percent_stroke                    -0.517325      -0.513597    -0.426976
# Percent_Diabetes                  -0.532908      -0.528797    -0.470819
# Percent_heart                     -0.308270      -0.307402    -0.193489
# Percent_uninsured                 -0.235292      -0.227701    -0.193791
# Percent_elem                       0.097688       0.099677     0.053263
# Percent_mid                       -0.010932      -0.006951     0.001001
# Percent_high                       0.139428       0.137111     0.167858
# Percent_unaccounted               -0.185549      -0.188044    -0.170706
# avg_score_read_4                   0.814855       0.814526     0.780561
# avg_score_math_4                   0.827665       0.827106     0.807694
# diff_math_4                        0.827665       0.827106     0.807694
# math_AB_4                          0.746411       0.744816     0.781068
# math_AP_4                          0.853256       0.851531     0.831359
# avg_score_read_8th                 0.889547       0.890154     0.849045
# avg_math_score_8th                 1.000000       0.999732     0.966059
# diff_math_8th                      0.999732       1.000000     0.965868
# math_AB_8th                        0.966059       0.965868     1.000000
# math_AP_8th                        0.982567       0.982309     0.926050
# Percentage_MMR                     0.243547       0.248081     0.213206
# Percentage_HPV                     0.193468       0.192669     0.127487
# Percentage_HepB                    0.308268       0.311392     0.255302
# Percentage_Pneumococcal            0.347888       0.346593     0.403545
#
#                          math_AP_8th  Percentage_MMR  Percentage_HPV  \
# Percent_stroke             -0.574154       -0.223543       -0.602543
# Percent_Diabetes           -0.590890       -0.301477       -0.622127
# Percent_heart              -0.386344       -0.321120       -0.570962
# Percent_uninsured          -0.304735       -0.392323       -0.619117
# Percent_elem                0.093498        0.151131        0.345207
# Percent_mid                -0.028786        0.093196       -0.126393
# Percent_high                0.095045       -0.027854       -0.152669
# Percent_unaccounted        -0.139717       -0.174245       -0.144846
# avg_score_read_4            0.788724        0.307004        0.211994
# avg_score_math_4            0.798052        0.257225        0.145852
# diff_math_4                 0.798052        0.257225        0.145852
# math_AB_4                   0.687452        0.212029        0.025436
# math_AP_4                   0.836866        0.297041        0.176525
# avg_score_read_8th          0.871078        0.325594        0.208636
# avg_math_score_8th          0.982567        0.243547        0.193468
# diff_math_8th               0.982309        0.248081        0.192669
# math_AB_8th                 0.926050        0.213206        0.127487
# math_AP_8th                 1.000000        0.280931        0.255409
# Percentage_MMR              0.280931        1.000000        0.551854
# Percentage_HPV              0.255409        0.551854        1.000000
# Percentage_HepB             0.342610        0.897793        0.567717
# Percentage_Pneumococcal     0.311159        0.077152        0.223388
#
#                          Percentage_HepB  Percentage_Pneumococcal
# Percent_stroke                 -0.255445                -0.091611
# Percent_Diabetes               -0.287048                -0.130176
# Percent_heart                  -0.276902                 0.075005
# Percent_uninsured              -0.425060                -0.210458
# Percent_elem                    0.264140                 0.130669
# Percent_mid                     0.028612                 0.201024
# Percent_high                   -0.017600                 0.244440
# Percent_unaccounted            -0.249694                -0.412610
# avg_score_read_4                0.391244                 0.292301
# avg_score_math_4                0.281887                 0.217523
# diff_math_4                     0.281887                 0.217523
# math_AB_4                       0.227220                 0.212722
# math_AP_4                       0.312506                 0.214281
# avg_score_read_8th              0.433807                 0.376926
# avg_math_score_8th              0.308268                 0.347888
# diff_math_8th                   0.311392                 0.346593
# math_AB_8th                     0.255302                 0.403545
# math_AP_8th                     0.342610                 0.311159
# Percentage_MMR                  0.897793                 0.077152
# Percentage_HPV                  0.567717                 0.223388
# Percentage_HepB                 1.000000                 0.116996
# Percentage_Pneumococcal         0.116996                 1.000000
#
# [22 rows x 22 columns]

# %%
corr_matrix=big_df[['Percent_heart', 'Percent_stroke', 'Percent_Diabetes', 'Percent_uninsured', 'avg_score_read_4', 'avg_score_read_8th','avg_score_math_4','avg_math_score_8th', 'Percentage_MMR', 'Percentage_HPV','Percentage_HepB', 'Percentage_Pneumococcal']].corr()

# %%
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False).figure.savefig('healthdata2019.png')

# %%
Df1819=big_df

# %%
Df1819=Df1819.drop(columns=['Percent_elem', 'Percent_High', 'Percent_mid', 'Percent_unaccounted'])

# %%
Df1819
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12404\391933705.py in <module>
# ----> 1 Df1819
#
# NameError: name 'Df1819' is not defined

# %%
Df1819.to_csv('HealthSchool_data_1819.csv')

# %%
places_2023=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/places_2023.csv')

# %%
# Out:
# array(['All teeth lost among adults aged >=65 years'], dtype=object)

# %%
stroke_2021=places_2023.loc[(places_2023['Year']==2021)&(places_2023['Measure']=='Stroke among adults aged >=18 years')&(places_2023['Data_Value_Type']=='Crude prevalence')]

# %%
stroke2021_percent=pd.DataFrame()

# %%
for i in state_list:
    stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2700322976.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stroke2021_percent=stroke2021_percent.append(stroke_2021.loc[(stroke_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())

# %%
stroke2021_percent=stroke2021_percent.sort_values('StateAbbr')

# %%
stroke2021_percent=stroke2021_percent.reset_index().rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_stroke'})

# %%
places_2023.Measure.unique()
# Out:
# array(['All teeth lost among adults aged >=65 years',
#        'Arthritis among adults aged >=18 years',
#        'Obesity among adults aged >=18 years',
#        'Any disability among adults aged >=18 years',
#        'Current asthma among adults aged >=18 years',
#        'Stroke among adults aged >=18 years',
#        'High blood pressure among adults aged >=18 years',
#        'Mammography use among women aged 50-74 years',
#        'Depression among adults aged >=18 years',
#        'Vision disability among adults aged >=18 years',
#        'Diagnosed diabetes among adults aged >=18 years',
#        'Binge drinking among adults aged >=18 years',
#        'Mobility disability among adults aged >=18 years',
#        'Hearing disability among adults aged >=18 years',
#        'Taking medicine for high blood pressure control among adults aged >=18 years with high blood pressure',
#        'Coronary heart disease among adults aged >=18 years',
#        'Cognitive disability among adults ages >=18 years',
#        'No leisure-time physical activity among adults aged >=18 years',
#        'Older adult men aged >=65 years who are up to date on a core set of clinical preventive services: Flu shot past year, PPV shot ever, Colorectal cancer screening',
#        'Visits to doctor for routine checkup within the past year among adults aged >=18 years',
#        'Cancer (excluding skin cancer) among adults aged >=18 years',
#        'Mental health not good for >=14 days among adults aged >=18 years',
#        'Independent living disability among adults aged >=18 years',
#        'Visits to dentist or dental clinic among adults aged >=18 years',
#        'Chronic obstructive pulmonary disease among adults aged >=18 years',
#        'Self-care disability among adults aged >=18 years',
#        'Current smoking among adults aged >=18 years',
#        'Physical health not good for >=14 days among adults aged >=18 years',
#        'Current lack of health insurance among adults aged 18-64 years',
#        'Sleeping less than 7 hours among adults aged >=18 years',
#        'High cholesterol among adults aged >=18 years who have been screened in the past 5 years',
#        'Cholesterol screening among adults aged >=18 years',
#        'Fecal occult blood test, sigmoidoscopy, or colonoscopy among adults aged 50-75 years',
#        'Chronic kidney disease among adults aged >=18 years',
#        'Cervical cancer screening among adult women aged 21-65 years',
#        'Fair or poor self-rated health status among adults aged >=18 years',
#        'Older adult women aged >=65 years who are up to date on a core set of clinical preventive services: Flu shot past year, PPV shot ever, Colorectal cancer screening, and Mammogram past 2 years'],
#       dtype=object)

# %%
places_2023.groupby('Year').count()
# Out:
#       StateAbbr  StateDesc  LocationName  DataSource  Category  Measure  \
# Year
# 2020     455534     455534        455534      455534    455534   455534
# 2021    1599234    1599234       1599234     1599234   1599234  1599234
#
#       Data_Value_Unit  Data_Value_Type  Data_Value  \
# Year
# 2020           455534           455534      447213
# 2021          1599234          1599234     1569016
#
#       Data_Value_Footnote_Symbol  Data_Value_Footnote  Low_Confidence_Limit  \
# Year
# 2020                        8321                 8321                447213
# 2021                       30218                30218               1569016
#
#       High_Confidence_Limit  TotalPopulation  Geolocation  LocationID  \
# Year
# 2020                 447213           455534       455534      455534
# 2021                1569016          1599234      1599234     1599234
#
#       CategoryID  MeasureId  DataValueTypeID  Short_Question_Text
# Year
# 2020      455534     455534           455534               455534
# 2021     1599234    1599234          1599234              1599234

# %%
diabetes_2021=places_2023.loc[(places_2023['Year']==2021)&(places_2023['Measure']=='Diagnosed diabetes among adults aged >=18 years')&(places_2023['Data_Value_Type']=='Crude prevalence')]

# %%
diabetes2021_percent=pd.DataFrame()

# %%
for i in state_list:
    diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3776226626.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   diabetes2021_percent=diabetes2021_percent.append(diabetes_2021.loc[(diabetes_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())

# %%
diabetes2021_percent=diabetes2021_percent.sort_values('StateAbbr')

# %%
diabetes2021_percent=diabetes2021_percent.reset_index().rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_diabetes'})

# %%
heart_2021=places_2023.loc[(places_2023['Year']==2021)&(places_2023['Measure']=='Coronary heart disease among adults aged >=18 years')&(places_2023['Data_Value_Type']=='Crude prevalence')]

# %%
heart2021_percent=pd.DataFrame()

# %%
for i in state_list:
    heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\3957433715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   heart2021_percent=heart2021_percent.append(heart_2021.loc[(heart_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())

# %%
heart2021_percent=heart2021_percent.sort_values('StateAbbr')

# %%
heart2021_percent=heart2021_percent.reset_index().rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_coronary'})

# %%
uninsured_2021=places_2023.loc[(places_2023['Year']==2021)&(places_2023['Measure']=='Current lack of health insurance among adults aged 18-64 years')&(places_2023['Data_Value_Type']=='Crude prevalence')]

# %%
ins2021_percent=pd.DataFrame()

# %%
for i in state_list:
    ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# Out:
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())
# C:\Users\Evan\AppData\Local\Temp\ipykernel_12404\2812279409.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ins2021_percent=ins2021_percent.append(uninsured_2021.loc[(uninsured_2021['StateDesc']==i), ('Data_Value', 'StateAbbr')].groupby('StateAbbr').mean())

# %%
ins2021_percent=ins2021_percent.sort_values('StateAbbr')

# %%
ins2021_percent=ins2021_percent.reset_index().rename(columns={'StateAbbr':'State', 'Data_Value':'Percent_uninsured'})

# %%
health_data2021=heart2021_percent.merge(diabetes2021_percent, how='inner', on='State')

# %%
health_data2021=health_data2021.merge(stroke2021_percent, how='inner', on='State')

# %%
health_data2021=health_data2021.merge(ins2021_percent, how='inner', on='State')

# %%
math_2022_4=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Math_2022_4.csv')

# %%
math_2022_4=math_2022_4.drop(columns=['SigSymbol'])

# %%
math_2022_4th=math_2022_4.rename(columns={'Jurisdiction':'State', 'MN':'avg_math_4th', 'SigDiff':'diff_math_4th', 'AB':'math_AB_4th', 'AP':'math_AP_4th'})

# %%
math_2022_4th
# Out:
#     State  avg_math_4th  diff_math_4th  math_AB_4th math_AP_4th
# 0   DoDEA           250             15           92          51
# 1      WY           243              8           84          44
# 2      MA           242              7           79          43
# 3      NE           242              7           80          43
# 4      FL           241              6           81          41
# 5      WI           240              5           79          43
# 6      ND           240              5           81          40
# 7      IA           240              5           80          40
# 8      UT           240              5           78          42
# 9      NH           239              5           80          40
# 10     NJ           239              4           77          39
# 11     IN           239              4           78          40
# 12     MN           239              4           78          41
# 13     SD           239              4           80          40
# 14     TX           239              4           78          38
# 15     MN           239              4           80          38
# 16     OH           238              3           76          40
# 17     PA           238              3           76          40
# 18     IL           237              2           76          38
# 19     HI           237              2           77          37
# 20     VA           236              1           75          38
# 21     CT           236              1           74          37
# 22     TN           236              1           76          36
# 23     ID           236              1           76          36
# 24     CO           236              1           75          36
# 25     NC           236              1           75          35
# 26     KS           235              0           75          35
# 27     WA           235              0           74          35
# 28     GA           235              0           75          34
# 29     US           235              0           74          35
# 30     VT           234             -1           74          34
# 31     SC           234             -1           74          34
# 32     RI           234             -1           74          34
# 33     KY           234             -1           75          33
# 34     MS           234             -1           74          32
# 35     ME           233             -2           75          32
# 36     MO           232             -2           72          34
# 37     MI           232             -3           71          32
# 38     AZ           232             -3           70          32
# 39     CA           230             -4           67          30
# 40     AL           230             -5           71          27
# 41     OK           229             -5           71          27
# 42     NV           229             -6           69          28
# 43     MD           229             -6           65          31
# 44     LA           229             -6           69          27
# 45     OR           228             -7           66          29
# 46     AR           228             -7           69          28
# 47     NY           227             -8           66          28
# 48     WV           226             -9           67          23
# 49     AK           226             -9           65          28
# 50     DE           226             -9           64          26
# 51     DC           223            -12           57          24
# 52     NM           221            -14           60          19
# 53     PR           178            -57           10           #

# %%
reading_2022_4th=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Reading_2022_4.csv')

# %%
reading_2022_4th=reading_2022_4th.drop(columns=['SigSymbol'])

# %%
reading_2022_4th=reading_2022_4th.rename(columns={'Jurisdiction':'State', 'MN':'avg_read_4th', 'SigDiff':'diff_read_4th', 'AB':'read_AB_4th', 'AP':'read_AP_4th'})

# %%
reading_2022_4th
# Out:
#    State  avg_read_4th  diff_read_4th  read_AB_4th  read_AP_4th
# 0     MA           227             11           70           43
# 1     WY           225              9           71           38
# 2     FL           225              9           71           39
# 3     CO           223              7           68           38
# 4     NJ           223              7           67           38
# 5     NH           223              6           67           37
# 6     UT           221              5           67           37
# 7     CT           219              3           64           35
# 8     PA           219              3           64           34
# 9     HI           219              3           64           35
# 10    MT           219              3           65           34
# 11    NE           219              3           65           34
# 12    OH           219              2           65           35
# 13    SD           218              2           65           32
# 14    IA           218              2           64           33
# 15    IL           218              2           62           33
# 16    ND           218              1           65           31
# 17    WI           217              1           63           33
# 18    IN           217              1           63           33
# 19    RI           217              1           62           34
# 20    MS           217              1           63           31
# 21    VT           217              1           62           34
# 22    WA           217              1           61           34
# 23    KY           217              0           62           31
# 24    SC           216              0           61           32
# 25    NC           216              0           61           32
# 26    US           216              0           61           32
# 27    GA           216              0           61           32
# 28    AZ           215             -1           61           31
# 29    MN           215             -1           61           32
# 30    ID           215             -1           61           32
# 31    KS           215             -1           60           31
# 32    CA           214             -2           58           31
# 33    TX           214             -2           58           30
# 34    VA           214             -2           60           32
# 35    TN           214             -2           59           30
# 36    NY           214             -3           58           30
# 37    MO           213             -3           60           30
# 38    AL           213             -3           59           28
# 39    ME           213             -3           60           29
# 40    MD           212             -4           56           31
# 41    LA           212             -4           57           28
# 42    AR           212             -4           58           30
# 43    MI           212             -4           58           28
# 44    NV           212             -5           57           27
# 45    OR           210             -6           56           28
# 46    DE           208             -8           53           25
# 47    OK           208             -8           55           24
# 48    DC           207             -9           50           26
# 49    WV           205            -11           52           22
# 50    AK           204            -12           51           24
# 51    NM           202            -14           48           21

# %%
reading_2022_8th=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Reading_2022_8.csv')

# %%
reading_2022_8th=reading_2022_8th.drop(columns=['SigSymbol'])

# %%
reading_2022_4th.dtypes
# Out:
# State            object
# avg_read_4th      int64
# diff_read_4th     int64
# read_AB_4th       int64
# read_AP_4th       int64
# dtype: object

# %%
reading_2022_8th.dtypes
# Out:
# Jurisdiction    object
# MN               int64
# SigDiff          int64
# AB               int64
# AP               int64
# dtype: object

# %%
reading_2022_8th=reading_2022_8th.rename(columns={'Jurisdiction':'State', 'MN':'avg_read_8th', 'SigDiff':'diff_read_8th', 'AB':'read_AB_8th', 'AP':'read_AP_8th'})

# %%
math_2022_8th=pd.read_csv('C:/Users/Evan/Desktop/NSS/Python/Capstone/data/Math_2022_8.csv')

# %%
math_2022_8th=math_2022_8th.drop(columns=['SigSymbol'])

# %%
math_2022_8th=math_2022_8th.rename(columns={'Jurisdiction':'State', 'MN':'avg_math_8th', 'SigDiff':'diff_math_8th', 'AB':'math_AB_8th', 'AP':'math_AP_8th'})

# %%
math_2022_8th
# Out:
#    State  avg_math_8th  diff_math_8th  math_AB_8th  math_AP_8th
# 0     MA           284             10           70           35
# 1     UT           282              9           70           35
# 2     ID           282              9           71           32
# 3     SD           281              8           72           32
# 4     WI           281              8           70           33
# 5     WY           281              8           72           31
# 6     NJ           281              8           67           33
# 7     MN           280              7           69           32
# 8     NE           279              6           68           31
# 9     VA           279              6           65           31
# 10    IN           279              6           66           30
# 11    NH           279              5           70           29
# 12    ND           278              5           69           28
# 13    MT           277              4           68           29
# 14    IA           277              4           67           28
# 15    CT           276              3           63           30
# 16    VT           276              3           66           27
# 17    WA           276              3           64           28
# 18    OH           276              3           64           29
# 19    IL           275              2           62           27
# 20    CO           275              2           63           28
# 21    PA           274              1           62           27
# 22    NY           274              1           60           28
# 23    NC           274              1           61           25
# 24    US           273              0           60           26
# 25    TX           273              0           61           24
# 26    MI           273             -1           60           25
# 27    ME           273             -1           61           24
# 28    MO           272             -1           61           24
# 29    TN           272             -1           60           25
# 30    KS           272             -1           61           23
# 31    GA           271             -2           59           24
# 32    FL           271             -2           58           23
# 33    AZ           271             -2           58           24
# 34    RI           270             -3           58           24
# 35    OR           270             -3           57           22
# 36    HI           270             -3           58           22
# 37    AK           270             -3           59           23
# 38    CA           270             -3           56           23
# 39    KY           269             -4           57           21
# 40    NV           269             -4           56           21
# 41    SC           269             -4           56           22
# 42    MD           269             -4           54           25
# 43    AR           267             -6           55           19
# 44    LA           266             -8           53           19
# 45    MS           266             -8           54           18
# 46    AL           264             -9           53           19
# 47    DE           264             -9           51           18
# 48    OK           264             -9           52           16
# 49    WV           260            -13           48           15
# 50    DC           260            -14           46           16
# 51    NM           259            -14           45           13

# %%
big_df2=health_data2021.merge(reading_2022_4th, how='right', left_on='State', right_on='State')

# %%
big_df2=big_df2.merge(reading_2022_8th, how='left', on='State')

# %%
big_df2=big_df2.merge(math_2022_4th, how='left', on='State')

# %%
big_df2=big_df2.merge(math_2022_8th, how='left', on='State')

# %%
big_df2=big_df2.merge(vax_df, how='left', on='State')

# %%
big_df2=big_df2.merge(school_perc, how='left', on='State')

# %%
big

# %%
big_df2.to_csv('healthschool_data_2021.csv')

# %%
big_df2.columns
# Out:
# Index(['State', 'Percent_coronary', 'Percent_diabetes', 'Percent_stroke',
#        'Percent_uninsured', 'avg_read_4th', 'diff_read_4th', 'read_AB_4th',
#        'read_AP_4th', 'avg_read_8th', 'diff_read_8th', 'read_AB_8th',
#        'read_AP_8th', 'avg_math_4th', 'diff_math_4th', 'math_AB_4th',
#        'math_AP_4th', 'avg_math_8th', 'diff_math_8th', 'math_AB_8th',
#        'math_AP_8th', 'Percentage_MMR', 'Percent_pneumococcal',
#        'Percentage_HepB', 'Percentage_HPV', 'Percent_elem', 'Percent_High',
#        'Percent_mid', 'Percent_unaccounted'],
#       dtype='object')

# %%
big_df.columns
# Out:
# Index(['State', 'Percent_stroke', 'Percent_Diabetes', 'Percent_heart',
#        'Percent_uninsured', 'Percent_elem', 'Percent_mid', 'Percent_high',
#        'Percent_unaccounted', 'avg_score_read_4', 'diff_read_4', 'read_AB_4',
#        'read_AP_4', 'avg_score_math_4', 'diff_math_4', 'math_AB_4',
#        'math_AP_4', 'avg_score_read_8th', 'diff_read_8th', 'read_AB_8th',
#        'read_AP_8th', 'avg_math_score_8th', 'diff_math_8th', 'math_AB_8th',
#        'math_AP_8th', 'Percentage_MMR', 'Percentage_HPV', 'Percentage_HepB',
#        'Percentage_Pneumococcal'],
#       dtype='object')

# %%
corr_matrix2=big_df2[['Percent_coronary', 'Percent_stroke', 'Percent_diabetes', 'Percent_uninsured', 'avg_read_4th', 'avg_read_8th','avg_math_4th','avg_math_8th', 'Percentage_MMR', 'Percentage_HPV','Percentage_HepB', 'Percent_pneumococcal']].corr(method='pearson')

# %%
sns.heatmap(corr_matrix2, cmap='coolwarm', annot=False)
# Out:
# <AxesSubplot:>

# %%
Df2122=pd.DataFrame()
